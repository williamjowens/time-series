# %% [markdown]
# # Installs & Imports

# %%
import math
from itertools import product
from functools import lru_cache
from joblib import Parallel, delayed
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.discrete.discrete_model as dm
from patsy import dmatrices
import statsmodels.graphics.tsaplots as tsa
from matplotlib import pyplot as plt
from scipy.stats import poisson, binom, nbinom, norm
from scipy.special import logsumexp
from statsmodels.base.model import GenericLikelihoodModel, GenericLikelihoodModelResults
from sklearn.metrics import mean_squared_error, mean_absolute_error
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load the Data

# %%
# Load the STRIKES dataset from the 'Ecdat' package
strikes_dataset = sm.datasets.get_rdataset(dataname='StrikeNb', package='Ecdat')
strikes_data = strikes_dataset.data.copy()

# Generate actual date information
strikes_data['date'] = pd.date_range(start='1968-01-01', periods=len(strikes_data), freq='MS')

# %%
# Display the first few rows of the dataset
print("=== Dataset Head ===")
display(strikes_data.head())

print("\n=== Dataset Tail ===")
display(strikes_data.tail())
# Out:
# === Dataset Head ===
#    strikes   output  time       date
# 0        5  0.01517     1 1968-01-01
# 1        4  0.00997     2 1968-02-01
# 2        6  0.01170     3 1968-03-01
# 3       16  0.00473     4 1968-04-01
# 4        5  0.01277     5 1968-05-01
# === Dataset Tail ===
#      strikes   output  time       date
# 103        3  0.00134   104 1976-08-01
# 104        4 -0.12810   105 1976-09-01
# 105        6 -0.01538   106 1976-10-01
# 106        2 -0.00703   107 1976-11-01
# 107        3 -0.00003   108 1976-12-01

# %%
# Plot the time series of strikes
plt.figure(figsize=(12, 6))
plt.plot(strikes_data['date'], strikes_data['strikes'], marker='o', linestyle='-')
plt.title('Monthly Strike Counts in U.S. Manufacturing (1968-1976)')
plt.xlabel('Date')
plt.ylabel('Number of Strikes')
plt.grid(True)
plt.show()

# %% [markdown]
# # Explore the Data

# %%
# Display summary statistics
print("=== Summary Statistics ===")
display(strikes_data['strikes'].describe())
# Out:
# === Summary Statistics ===
# count    108.000000
# mean       5.240741
# std        3.751312
# min        0.000000
# 25%        2.000000
# 50%        5.000000
# 75%        8.000000
# max       18.000000
# Name: strikes, dtype: float64

# %%
# Check for overdispersion (Variance > Mean)
mean_strikes = strikes_data['strikes'].mean()
variance_strikes = strikes_data['strikes'].var()
print(f"Mean of Strikes: {mean_strikes:.2f}")
print(f"Variance of Strikes: {variance_strikes:.2f}")

if variance_strikes > mean_strikes:
    print("The data is overdispersed (Variance > Mean).")
else:
    print("The data is not overdispersed (Variance <= Mean).")
# Out:
# Mean of Strikes: 5.24
# Variance of Strikes: 14.07
# The data is overdispersed (Variance > Mean).

# %%
# Check autocorrelation using ACF plot
tsa.plot_acf(strikes_data['strikes'], lags=20, alpha=0.05)
plt.title('Autocorrelation Function (ACF) of Strikes')
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.show()

# %% [markdown]
# # Preprocess the Data

# %%
def create_percent_change(df, target):
    """
    Create a 'percent_change' column for the target variable.

    Parameters:
    - df: Pandas DataFrame.
    - target: String, name of the target column.

    Returns:
    - DataFrame with an added 'percent_change' column.
    """
    df[f'{target}_percent_change'] = df[target].pct_change() * 100
    # Replace infinite values with 0
    df[f'{target}_percent_change'].replace([np.inf, -np.inf], 0, inplace=True)
    return df

# Apply 'percent_change' to 'strikes'
strikes_data = create_percent_change(strikes_data, 'strikes')

# %%
def create_spike_indicator(df, target, quantile=0.95):
    """
    Create a binary 'spike' indicator where values above a certain quantile are marked as spikes.

    Parameters:
    - df: Pandas DataFrame.
    - target: String, name of the target column.
    - quantile: Float, quantile to define spike threshold.

    Returns:
    - DataFrame with an added 'spike' column.
    """
    spike_threshold = df[target].quantile(quantile)
    df['spike'] = (df[target] > spike_threshold).astype(int)
    return df

# Apply 'spike' indicator to 'strikes'
strikes_data = create_spike_indicator(strikes_data, 'strikes')

# %%
def create_zero_count_indicator(df, target):
    """
    Create a binary 'zero_count' indicator where values are marked as 0.

    Parameters:
    - df: Pandas DataFrame.
    - target: String, name of the target column.

    Returns:
    - DataFrame with an added 'zero_count' column.
    """
    df['zero_count'] = (df[target] == 0).astype(int)
    return df

# Apply 'zero_count' indicator to 'strikes'
strikes_data = create_zero_count_indicator(strikes_data, 'strikes')

# %%
# Verify derived variables
print("After Creating Derived Variables:")
display(strikes_data[['strikes', 'strikes_percent_change', 'spike', 'zero_count']].head(5))
# Out:
# After Creating Derived Variables:
#    strikes  strikes_percent_change  spike  zero_count
# 0        5                     NaN      0           0
# 1        4              -20.000000      0           0
# 2        6               50.000000      0           0
# 3       16              166.666667      1           0
# 4        5              -68.750000      0           0

# %%
def create_lagged_features(df, target, lags):
    """
    Create lagged features for a specified target variable.

    Parameters:
    - df: Pandas DataFrame.
    - target: String, name of the target column.
    - lags: Integer, number of lags to create.

    Returns:
    - DataFrame with added lagged features.
    """
    for lag in range(1, lags + 1):
        df[f'{target}_lag_{lag}'] = df[target].shift(lag)
    return df

# Apply lagging to 'strikes'
N = 2  # Number of lags
strikes_data = create_lagged_features(strikes_data, 'strikes', N)

# %%
# Apply lagging to exogenous variables
# Define exogenous variables to lag
exog_vars_to_lag = ['output', 'strikes_percent_change', 'spike', 'zero_count']

# Check if all exogenous variables exist
missing_vars = [var for var in exog_vars_to_lag if var not in strikes_data.columns]
if missing_vars:
    raise ValueError(f"The following exogenous variables are missing from the dataset and cannot be lagged: {missing_vars}")

# Apply lagging to each exogenous variable
for var in exog_vars_to_lag:
    strikes_data = create_lagged_features(strikes_data, var, N)

# %%
# Verify lagged variables
lagged_cols = [f'strikes_lag_{lag}' for lag in range(1, N+1)]
for var in exog_vars_to_lag:
    lagged_cols += [f'{var}_lag_{lag}' for lag in range(1, N+1)]
print("After Creating Lagged Variables:")
display(strikes_data[lagged_cols].head(5))
# Out:
# After Creating Lagged Variables:
#    strikes_lag_1  strikes_lag_2  output_lag_1  output_lag_2  \
# 0            NaN            NaN           NaN           NaN
# 1            5.0            NaN       0.01517           NaN
# 2            4.0            5.0       0.00997       0.01517
# 3            6.0            4.0       0.01170       0.00997
# 4           16.0            6.0       0.00473       0.01170
#
#    strikes_percent_change_lag_1  strikes_percent_change_lag_2  spike_lag_1  \
# 0                           NaN                           NaN          NaN
# 1                           NaN                           NaN          0.0
# 2                    -20.000000                           NaN          0.0
# 3                     50.000000                         -20.0          0.0
# 4                    166.666667                          50.0          1.0
#
#    spike_lag_2  zero_count_lag_1  zero_count_lag_2
# 0          NaN               NaN               NaN
# 1          NaN               0.0               NaN
# 2          0.0               0.0               0.0
# 3          0.0               0.0               0.0
# 4          0.0               0.0               0.0

# %%
def generate_fourier_terms(df, period, K):
    """
    Generate Fourier terms for capturing seasonality.

    Parameters:
    - df: Pandas DataFrame with a 'date' column.
    - period: Integer, number of periods in a complete seasonal cycle (e.g., 12 for monthly data).
    - K: Integer, number of Fourier harmonics.

    Returns:
    - DataFrame containing sine and cosine Fourier terms.
    """
    t = np.arange(len(df))
    fourier_terms = {}
    for k in range(1, K + 1):
        fourier_terms[f'sin_{k}'] = np.sin(2 * np.pi * k * t / period)
        fourier_terms[f'cos_{k}'] = np.cos(2 * np.pi * k * t / period)
    return pd.DataFrame(fourier_terms, index=df.index)

# %%
# Define seasonality parameters
period = 12  # Monthly data with yearly seasonality
K = 1        # Number of Fourier harmonics

# Generate and concatenate Fourier terms
fourier_terms_df = generate_fourier_terms(strikes_data, period, K)
strikes_data = pd.concat([strikes_data, fourier_terms_df], axis=1)

# Verify Fourier Terms
print("After Generating Fourier Terms:")
display(strikes_data[[f'sin_{k}' for k in range(1, K+1)] + [f'cos_{k}' for k in range(1, K+1)]].head(5))
# Out:
# After Generating Fourier Terms:
#       sin_1         cos_1
# 0  0.000000  1.000000e+00
# 1  0.500000  8.660254e-01
# 2  0.866025  5.000000e-01
# 3  1.000000  6.123234e-17
# 4  0.866025 -5.000000e-01

# %%
# Display initial information
print(f"Total Observations: {len(strikes_data)}")

# Drop rows with any NaN values resulting from lagging
strikes_data_clean = strikes_data.dropna().reset_index(drop=True)
print(f"\nTotal Observations after Dropping NaNs: {len(strikes_data_clean)}")
# Out:
# Total Observations: 108
#
# Total Observations after Dropping NaNs: 105

# %%
# Define split ratio
split_ratio = 0.8
split_point = int(len(strikes_data_clean) * split_ratio)

# Split the data
strikes_data_train = strikes_data_clean.iloc[:split_point].copy()
strikes_data_test = strikes_data_clean.iloc[split_point:].copy()

print(f"Training Set Size: {len(strikes_data_train)}")
print(f"Testing Set Size: {len(strikes_data_test)}")
# Out:
# Training Set Size: 84
# Testing Set Size: 21

# %%
def validate_data(df, dataset_name):
    """
    Validate that the DataFrame contains no NaN or infinite values.

    Parameters:
    - df: Pandas DataFrame.
    - dataset_name: String, name of the dataset (e.g., 'Training Data').

    Returns:
    - None. Prints validation results.
    """
    nan_counts = df.isna().sum()
    if nan_counts.any():
        print(f"Warning: {dataset_name} contains NaN values.")
        print(nan_counts[nan_counts > 0])
    else:
        print(f"{dataset_name} is clean.")

    # Check for infinite values in numeric columns
    numeric_df = df.select_dtypes(include=[np.number])
    if np.isinf(numeric_df.values).any():
        print(f"Warning: {dataset_name} contains infinite values.")
    else:
        print(f"{dataset_name} has no infinite values.")

# %%
# Validate training data
validate_data(strikes_data_train, "Training Data")
print("\n")

# Validate testing data
validate_data(strikes_data_test, "Testing Data")
# Out:
# Training Data is clean.
# Training Data has no infinite values.
#
#
# Testing Data is clean.
# Testing Data has no infinite values.

# %%
# Display sample data
print("Sample Training Data:")
display(strikes_data_train.head())
print("\n")
display(strikes_data_train.tail())
print("\n")
print("Sample Testing Data:")
display(strikes_data_test.head())
print("\n")
display(strikes_data_test.tail())
# Out:
# Sample Training Data:
#    strikes   output  time       date  strikes_percent_change  spike  \
# 0       16  0.00473     4 1968-04-01              166.666667      1
# 1        5  0.01277     5 1968-05-01              -68.750000      0
# 2        8  0.01138     6 1968-06-01               60.000000      0
# 3        8  0.00424     7 1968-07-01                0.000000      0
# 4        9 -0.00687     8 1968-08-01               12.500000      0
#
#    zero_count  strikes_lag_1  strikes_lag_2  output_lag_1  output_lag_2  \
# 0           0            6.0            4.0       0.01170       0.00997
# 1           0           16.0            6.0       0.00473       0.01170
# 2           0            5.0           16.0       0.01277       0.00473
# 3           0            8.0            5.0       0.01138       0.01277
# 4           0            8.0            8.0       0.00424       0.01138
#
#    strikes_percent_change_lag_1  strikes_percent_change_lag_2  spike_lag_1  \
# 0                     50.000000                    -20.000000          0.0
# 1                    166.666667                     50.000000          1.0
# 2                    -68.750000                    166.666667          0.0
# 3                     60.000000                    -68.750000          0.0
# 4                      0.000000                     60.000000          0.0
#
#    spike_lag_2  zero_count_lag_1  zero_count_lag_2         sin_1         cos_1
# 0          0.0               0.0               0.0  1.000000e+00  6.123234e-17
# 1          0.0               0.0               0.0  8.660254e-01 -5.000000e-01
# 2          1.0               0.0               0.0  5.000000e-01 -8.660254e-01
# 3          0.0               0.0               0.0  1.224647e-16 -1.000000e+00
# 4          0.0               0.0               0.0 -5.000000e-01 -8.660254e-01
#     strikes   output  time       date  strikes_percent_change  spike  \
# 79        7 -0.00225    83 1974-11-01                0.000000      0
# 80        0 -0.04998    84 1974-12-01             -100.000000      0
# 81        3 -0.09771    85 1975-01-01                0.000000      0
# 82        3 -0.12124    86 1975-02-01                0.000000      0
# 83        4 -0.13996    87 1975-03-01               33.333333      0
#
#     zero_count  strikes_lag_1  strikes_lag_2  output_lag_1  output_lag_2  \
# 79           0            7.0            9.0       0.03458       0.05197
# 80           1            7.0            7.0      -0.00225       0.03458
# 81           0            0.0            7.0      -0.04998      -0.00225
# 82           0            3.0            0.0      -0.09771      -0.04998
# 83           0            3.0            3.0      -0.12124      -0.09771
#
#     strikes_percent_change_lag_1  strikes_percent_change_lag_2  spike_lag_1  \
# 79                    -22.222222                    -10.000000          0.0
# 80                      0.000000                    -22.222222          0.0
# 81                   -100.000000                      0.000000          0.0
# 82                      0.000000                   -100.000000          0.0
# 83                      0.000000                      0.000000          0.0
#
#     spike_lag_2  zero_count_lag_1  zero_count_lag_2         sin_1     cos_1
# 79          0.0               0.0               0.0 -8.660254e-01  0.500000
# 80          0.0               0.0               0.0 -5.000000e-01  0.866025
# 81          0.0               1.0               0.0 -1.714506e-15  1.000000
# 82          0.0               0.0               1.0  5.000000e-01  0.866025
# 83          0.0               0.0               0.0  8.660254e-01  0.500000
# Sample Testing Data:
#     strikes   output  time       date  strikes_percent_change  spike  \
# 84        2 -0.12590    88 1975-04-01                   -50.0      0
# 85        1 -0.12224    89 1975-05-01                   -50.0      0
# 86        2 -0.10443    90 1975-06-01                   100.0      0
# 87        2 -0.08656    91 1975-07-01                     0.0      0
# 88        3 -0.06279    92 1975-08-01                    50.0      0
#
#     zero_count  strikes_lag_1  strikes_lag_2  output_lag_1  output_lag_2  \
# 84           0            4.0            3.0      -0.13996      -0.12124
# 85           0            2.0            4.0      -0.12590      -0.13996
# 86           0            1.0            2.0      -0.12224      -0.12590
# 87           0            2.0            1.0      -0.10443      -0.12224
# 88           0            2.0            2.0      -0.08656      -0.10443
#
#     strikes_percent_change_lag_1  strikes_percent_change_lag_2  spike_lag_1  \
# 84                     33.333333                      0.000000          0.0
# 85                    -50.000000                     33.333333          0.0
# 86                    -50.000000                    -50.000000          0.0
# 87                    100.000000                    -50.000000          0.0
# 88                      0.000000                    100.000000          0.0
#
#     spike_lag_2  zero_count_lag_1  zero_count_lag_2         sin_1  \
# 84          0.0               0.0               0.0  1.000000e+00
# 85          0.0               0.0               0.0  8.660254e-01
# 86          0.0               0.0               0.0  5.000000e-01
# 87          0.0               0.0               0.0 -1.715743e-15
# 88          0.0               0.0               0.0 -5.000000e-01
#
#            cos_1
# 84  7.104808e-15
# 85 -5.000000e-01
# 86 -8.660254e-01
# 87 -1.000000e+00
# 88 -8.660254e-01
#      strikes   output  time       date  strikes_percent_change  spike  \
# 100        3  0.00134   104 1976-08-01              -50.000000      0
# 101        4 -0.12810   105 1976-09-01               33.333333      0
# 102        6 -0.01538   106 1976-10-01               50.000000      0
# 103        2 -0.00703   107 1976-11-01              -66.666667      0
# 104        3 -0.00003   108 1976-12-01               50.000000      0
#
#      zero_count  strikes_lag_1  strikes_lag_2  output_lag_1  output_lag_2  \
# 100           0            6.0            9.0      -0.00157      -0.00700
# 101           0            3.0            6.0       0.00134      -0.00157
# 102           0            4.0            3.0      -0.12810       0.00134
# 103           0            6.0            4.0      -0.01538      -0.12810
# 104           0            2.0            6.0      -0.00703      -0.01538
#
#      strikes_percent_change_lag_1  strikes_percent_change_lag_2  spike_lag_1  \
# 100                    -33.333333                     80.000000          0.0
# 101                    -50.000000                    -33.333333          0.0
# 102                     33.333333                    -50.000000          0.0
# 103                     50.000000                     33.333333          0.0
# 104                    -66.666667                     50.000000          0.0
#
#      spike_lag_2  zero_count_lag_1  zero_count_lag_2     sin_1         cos_1
# 100          0.0               0.0               0.0 -0.500000 -8.660254e-01
# 101          0.0               0.0               0.0 -0.866025 -5.000000e-01
# 102          0.0               0.0               0.0 -1.000000  3.185939e-15
# 103          0.0               0.0               0.0 -0.866025  5.000000e-01
# 104          0.0               0.0               0.0 -0.500000  8.660254e-01

# %%
# Get the last train date and first test date
train_last_date = strikes_data_train['date'].iloc[-1]
test_first_date = strikes_data_test['date'].iloc[0]

# Calculate the average or midpoint between the two dates for an offset
split_line_position = train_last_date + (test_first_date - train_last_date) / 2

# Plot the train/test splits
plt.figure(figsize=(12, 6))
plt.plot(strikes_data_train['date'], strikes_data_train['strikes'], marker='o', linestyle='-', color='blue', label='Training Data')
plt.plot(strikes_data_test['date'], strikes_data_test['strikes'], marker='o', linestyle='-', color='orange', label='Testing Data')
plt.axvline(x=split_line_position, color='k', linestyle='--', label='Train/Test Split')
plt.title('Training and Testing Set Split')
plt.xlabel('Date')
plt.ylabel('Number of Strikes')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Fit the Models

# %% [markdown]
# ## Poisson Regression

# %%
# Define the regression formula
exog_vars = ['output', 'strikes_percent_change', 'spike', 'zero_count']
exog_lagged_terms = [f'{var}_lag_{lag}' for var in exog_vars for lag in range(1, N + 1)]
target_lagged_terms = [f'strikes_lag_{lag}' for lag in range(1, N + 1)]
fourier_terms = [f'sin_{k}' for k in range(1, K + 1)] + [f'cos_{k}' for k in range(1, K + 1)]
all_terms = exog_lagged_terms + target_lagged_terms + fourier_terms
expr_poisson = 'strikes ~ ' + ' + '.join(all_terms)

# Create design matrices using Patsy
y_train_poisson, X_train_poisson = dmatrices(expr_poisson, strikes_data_train, return_type='dataframe')
y_test_poisson, X_test_poisson = dmatrices(expr_poisson, strikes_data_test, return_type='dataframe')

# Fit the Poisson Regression Model
poisson_model = dm.Poisson(endog=y_train_poisson, exog=X_train_poisson)
poisson_results = poisson_model.fit(maxiter=100, disp=False)
print(poisson_results.summary())
print("\n")
print(poisson_results.summary2())
# Out:
#                           Poisson Regression Results
# ==============================================================================
# Dep. Variable:                strikes   No. Observations:                   84
# Model:                        Poisson   Df Residuals:                       71
# Method:                           MLE   Df Model:                           12
# Date:                Sun, 24 Nov 2024   Pseudo R-squ.:                  0.1868
# Time:                        07:03:52   Log-Likelihood:                -208.34
# converged:                       True   LL-Null:                       -256.19
# Covariance Type:            nonrobust   LLR p-value:                 3.853e-15
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.9517      0.149      6.375      0.000       0.659       1.244
# output_lag_1                     2.8970      4.441      0.652      0.514      -5.806      11.600
# output_lag_2                    -1.0730      4.549     -0.236      0.814      -9.990       7.844
# strikes_percent_change_lag_1    -0.0010      0.001     -1.223      0.221      -0.003       0.001
# strikes_percent_change_lag_2    -0.0010      0.001     -1.892      0.058      -0.002    3.72e-05
# spike_lag_1                     -0.6824      0.215     -3.175      0.001      -1.104      -0.261
# spike_lag_2                     -0.2491      0.230     -1.081      0.280      -0.701       0.202
# zero_count_lag_1                 0.4315      0.300      1.440      0.150      -0.156       1.019
# zero_count_lag_2                 0.1310      0.327      0.401      0.689      -0.510       0.772
# strikes_lag_1                    0.0802      0.023      3.547      0.000       0.036       0.124
# strikes_lag_2                    0.0536      0.027      1.962      0.050    4.51e-05       0.107
# sin_1                            0.2425      0.070      3.483      0.000       0.106       0.379
# cos_1                           -0.3511      0.084     -4.176      0.000      -0.516      -0.186
# ================================================================================================
#
#
#                               Results: Poisson
# ============================================================================
# Model:                   Poisson             Method:              MLE
# Dependent Variable:      strikes             Pseudo R-squared:    0.187
# Date:                    2024-11-24 07:03    AIC:                 442.6778
# No. Observations:        84                  BIC:                 474.2784
# Df Model:                12                  Log-Likelihood:      -208.34
# Df Residuals:            71                  LL-Null:             -256.19
# Converged:               1.0000              LLR p-value:         3.8526e-15
# No. Iterations:          6.0000              Scale:               1.0000
# ----------------------------------------------------------------------------
#                               Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# ----------------------------------------------------------------------------
# Intercept                     0.9517   0.1493  6.3749 0.0000  0.6591  1.2443
# output_lag_1                  2.8970   4.4406  0.6524 0.5141 -5.8063 11.6004
# output_lag_2                 -1.0730   4.5494 -0.2359 0.8135 -9.9898  7.8437
# strikes_percent_change_lag_1 -0.0010   0.0008 -1.2229 0.2214 -0.0026  0.0006
# strikes_percent_change_lag_2 -0.0010   0.0006 -1.8925 0.0584 -0.0021  0.0000
# spike_lag_1                  -0.6824   0.2149 -3.1747 0.0015 -1.1037 -0.2611
# spike_lag_2                  -0.2491   0.2304 -1.0812 0.2796 -0.7007  0.2025
# zero_count_lag_1              0.4315   0.2997  1.4396 0.1500 -0.1560  1.0190
# zero_count_lag_2              0.1310   0.3270  0.4006 0.6887 -0.5099  0.7719
# strikes_lag_1                 0.0802   0.0226  3.5472 0.0004  0.0359  0.1244
# strikes_lag_2                 0.0536   0.0273  1.9616 0.0498  0.0000  0.1072
# sin_1                         0.2425   0.0696  3.4828 0.0005  0.1060  0.3790
# cos_1                        -0.3511   0.0841 -4.1758 0.0000 -0.5158 -0.1863
# ============================================================================

# %% [markdown]
# ## Negative Binomial Regression

# %%
# Define the regression formula
expr_nb = 'strikes ~ ' + ' + '.join(all_terms)

# Create design matrices using Patsy
y_train_nb, X_train_nb = dmatrices(expr_nb, strikes_data_train, return_type='dataframe')
y_test_nb, X_test_nb = dmatrices(expr_nb, strikes_data_test, return_type='dataframe')

# Fit the Negative Binomial Regression Model (NB2)
nb_model = dm.NegativeBinomial(endog=y_train_nb, exog=X_train_nb, loglike_method='nb2')
nb_results = nb_model.fit(maxiter=3000, method='ncg')
print("\n")
print(nb_results.summary())
print("\n")
print(nb_results.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 2.436954
#          Iterations: 2
#          Function evaluations: 3
#          Gradient evaluations: 3
#          Hessian evaluations: 2
#
#
#                      NegativeBinomial Regression Results
# ==============================================================================
# Dep. Variable:                strikes   No. Observations:                   84
# Model:               NegativeBinomial   Df Residuals:                       71
# Method:                           MLE   Df Model:                           12
# Date:                Sun, 24 Nov 2024   Pseudo R-squ.:                 0.09579
# Time:                        07:03:52   Log-Likelihood:                -204.70
# converged:                       True   LL-Null:                       -226.39
# Covariance Type:            nonrobust   LLR p-value:                 1.954e-05
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.9517      0.200      4.762      0.000       0.560       1.343
# output_lag_1                     2.8970      5.783      0.501      0.616      -8.438      14.232
# output_lag_2                    -1.0730      5.896     -0.182      0.856     -12.628      10.482
# strikes_percent_change_lag_1    -0.0008      0.001     -0.800      0.424      -0.003       0.001
# strikes_percent_change_lag_2    -0.0009      0.001     -1.275      0.202      -0.002       0.001
# spike_lag_1                     -0.6824      0.321     -2.128      0.033      -1.311      -0.054
# spike_lag_2                     -0.2491      0.337     -0.740      0.459      -0.909       0.411
# zero_count_lag_1                 0.4315      0.380      1.135      0.256      -0.314       1.177
# zero_count_lag_2                 0.1310      0.414      0.317      0.752      -0.680       0.942
# strikes_lag_1                    0.0802      0.031      2.546      0.011       0.018       0.142
# strikes_lag_2                    0.0536      0.038      1.404      0.160      -0.021       0.128
# sin_1                            0.2425      0.097      2.511      0.012       0.053       0.432
# cos_1                           -0.3511      0.115     -3.059      0.002      -0.576      -0.126
# alpha                            0.1438      0.065      2.203      0.028       0.016       0.272
# ================================================================================================
#
#
#                           Results: NegativeBinomial
# =============================================================================
# Model:                  NegativeBinomial     Pseudo R-squared:     0.096
# Dependent Variable:     strikes              AIC:                  437.4082
# Date:                   2024-11-24 07:03     BIC:                  471.4397
# No. Observations:       84                   Log-Likelihood:       -204.70
# Df Model:               12                   LL-Null:              -226.39
# Df Residuals:           71                   LLR p-value:          1.9539e-05
# Converged:              1.0000               Scale:                1.0000
# Method:                 MLE
# -----------------------------------------------------------------------------
#                               Coef.  Std.Err.    z    P>|z|   [0.025   0.975]
# -----------------------------------------------------------------------------
# Intercept                     0.9517   0.1998  4.7623 0.0000   0.5600  1.3434
# output_lag_1                  2.8970   5.7834  0.5009 0.6164  -8.4383 14.2324
# output_lag_2                 -1.0730   5.8957 -0.1820 0.8556 -12.6285 10.4824
# strikes_percent_change_lag_1 -0.0008   0.0010 -0.8003 0.4235  -0.0029  0.0012
# strikes_percent_change_lag_2 -0.0009   0.0007 -1.2746 0.2024  -0.0024  0.0005
# spike_lag_1                  -0.6824   0.3207 -2.1276 0.0334  -1.3110 -0.0538
# spike_lag_2                  -0.2491   0.3367 -0.7399 0.4594  -0.9090  0.4108
# zero_count_lag_1              0.4315   0.3802  1.1350 0.2564  -0.3136  1.1766
# zero_count_lag_2              0.1310   0.4139  0.3165 0.7516  -0.6802  0.9422
# strikes_lag_1                 0.0802   0.0315  2.5464 0.0109   0.0185  0.1418
# strikes_lag_2                 0.0536   0.0382  1.4045 0.1602  -0.0212  0.1284
# sin_1                         0.2425   0.0966  2.5107 0.0120   0.0532  0.4318
# cos_1                        -0.3511   0.1148 -3.0591 0.0022  -0.5760 -0.1261
# alpha                         0.1438   0.0653  2.2031 0.0276   0.0159  0.2718
# =============================================================================

# %% [markdown]
# ## Poisson INAR Model

# %%
# Identify max counts in the data
max_counts = strikes_data_train['strikes'].max()
print(f"Maximum Count in Data: {max_counts}")
# Out:
# Maximum Count in Data: 18

# %%
# Top-level function for cached binomial PMF
@lru_cache(maxsize=None)
def binom_logpmf_cached(j, y_prev, rho_i):
    """
    Cached function to compute the logarithm of the Binomial probability mass function.

    Parameters:
    - j (int): Number of successes.
    - y_prev (int): Number of trials.
    - rho_i (float): Probability of success.

    Returns:
    - float: Logarithm of the Binomial PMF value.
    """
    return binom.logpmf(j, y_prev, rho_i)

# Top-level function to compute total log probability for Poisson INAR using log-space
def compute_total_log_prob_pois_logspace(y_t, y_lags, rho, mu_t, max_j):
    """
    Compute the log probability for a single observation in Poisson INAR using log-space calculations.

    This function calculates the log probability of observing count `y_t` given the past counts `y_lags`,
    thinning parameters `rho`, and the Poisson innovation term `mu_t`. It considers all valid combinations
    of retained counts from each lag, up to a maximum threshold `max_j`.

    Parameters:
    - y_t (int): Observed count at time t.
    - y_lags (tuple of ints): Array of lagged counts.
    - rho (tuple of floats): Array of thinning parameters.
    - mu_t (float): Mean of the Poisson innovation term at time t.
    - max_j (int): Maximum number of retained counts to consider for each lag.

    Returns:
    - float: Log probability for observation t.
    """
    log_probs = []

    # Define the range of retained counts for each lag based on y_prev and max_j
    j_ranges = [range(0, min(int(y_prev), max_j) + 1) for y_prev in y_lags]

    # Iterate over all possible combinations of retained counts across lags
    for j_tuple in product(*j_ranges):
        j_total = sum(j_tuple)

        # Skip combinations where total retained counts exceed observed count
        if j_total > y_t:
            continue  # Invalid combination, skip

        log_p_combination = 0.0
        valid = True

        # Calculate the log probability for each retained count in the combination
        for j_i, y_prev, rho_i in zip(j_tuple, y_lags, rho):
            if j_i > y_prev:
                valid = False  # Invalid retained count, skip this combination
                break
            log_p_j_i = binom_logpmf_cached(j_i, y_prev, rho_i)
            if not np.isfinite(log_p_j_i):
                valid = False  # Non-finite log probability, skip
                break
            log_p_combination += log_p_j_i

        if not valid:
            continue  # Skip invalid combinations

        # Calculate the log probability of the Poisson innovation term
        log_p_k = poisson.logpmf(y_t - j_total, mu_t)
        if not np.isfinite(log_p_k):
            continue  # Invalid Poisson PMF, skip

        # Append the combined log probability
        log_probs.append(log_p_combination + log_p_k)

    if not log_probs:
        return np.log(1e-10)  # Prevent log(0) by assigning a very small probability

    # Use log-sum-exp for numerical stability
    return logsumexp(log_probs)

# %%
class PoissonINARResults(GenericLikelihoodModelResults):
    """
    Custom results class for the Poisson INAR model, extending GenericLikelihoodModelResults.

    This class provides a Pandas Series for parameter estimates and a customized summary method.
    """
    def __init__(self, model, mlefit, param_names):
        """
        Initialize the PoissonINARResults object.

        Parameters:
        - model (GenericLikelihoodModel): The fitted Poisson INAR model.
        - mlefit: The Maximum Likelihood Estimation result.
        - param_names (list of str): Names of the parameters.
        """
        super().__init__(model, mlefit)
        self._param_names = param_names
        self.mlefit = mlefit

    @property
    def params(self):
        """
        Retrieve the parameter estimates as a Pandas Series with named indices.

        Returns:
        - pd.Series: Parameter estimates with names.
        """
        return pd.Series(self.mlefit.params, index=self._param_names)

    def summary(self, yname=None, xname=None, title=None, alpha=.05):
        """
        Generate a summary of the model results.

        Parameters:
        - yname (str, optional): Name of the dependent variable.
        - xname (list of str, optional): Names of the exogenous variables.
        - title (str, optional): Title of the summary.
        - alpha (float, optional): Significance level for confidence intervals.

        Returns:
        - Summary: A summary object containing parameter estimates and statistics.
        """
        if xname is None:
            xname = self._param_names
        return super().summary(yname=yname, xname=xname, title=title, alpha=alpha)

# %%
class PoissonINAR(GenericLikelihoodModel):
    """
    Poisson INAR (Integer-valued Autoregressive) Model.

    This model is suitable for count data with autocorrelation, modeling the current count as a
    combination of thinned past counts and a Poisson-distributed innovation term.

    Attributes:
    - p (int): Number of autoregressive lags.
    - n_jobs (int): Number of parallel jobs for computation.
    - max_j (int): Maximum number of retained counts to consider per lag.
    - var_names (list of str): Names of the exogenous variables.
    """

    def __init__(self, endog, exog, p=1, n_jobs=-1, max_j=12, **kwds):
        """
        Initialize the Poisson INAR model.

        Parameters:
        - endog (array-like): The dependent variable (count data).
        - exog (array-like): The exogenous variables (predictors), excluding lagged counts.
        - p (int, optional): Number of autoregressive lags. Default is 1.
        - n_jobs (int, optional): Number of parallel jobs for computation. Default is -1 (all cores).
        - max_j (int, optional): Maximum number of retained counts to consider per lag. Default is 12.
        - **kwds: Additional keyword arguments for GenericLikelihoodModel.
        """
        self.p = p  # Number of AR terms
        self.n_jobs = n_jobs  # Number of parallel jobs
        self.max_j = max_j  # Maximum count to consider per lag

        # Extract variable names if exog is a DataFrame; else, generate generic names
        if isinstance(exog, pd.DataFrame):
            self.var_names = exog.columns.tolist()
        else:
            self.var_names = [f'x{i+1}' for i in range(exog.shape[1])]

        super(PoissonINAR, self).__init__(endog, exog, **kwds)

    def nloglikeobs(self, params):
        """
        Compute the negative log-likelihood for each observation.

        This function calculates the negative log-likelihood by summing the log probabilities
        of observing each count, given the past counts and exogenous variables.

        Parameters:
        - params (array-like): Parameter vector [beta coefficients..., gamma1, gamma2, ..., gamma_p].

        Returns:
        - np.ndarray: Negative log-likelihood values for each observation.
        """
        num_beta = self.exog.shape[1]
        beta = params[:num_beta]   # Regression coefficients
        gamma = params[num_beta:]  # Thinning parameters

        # Logistic transformation to ensure rho is between 0 and 1
        rho = 1.0 / (1.0 + np.exp(-gamma))  # rho = [rho1, rho2, ..., rho_p]

        # Linear predictor for Poisson mean
        mu = np.exp(np.dot(self.exog, beta))  # mu = exp(X * beta)

        # Prepare arguments for parallel processing
        obs_args = [
            (self.endog[t], self.endog[t - self.p:t], tuple(rho), mu[t])
            for t in range(self.p, len(self.endog))
        ]

        # Compute log probabilities in parallel using the 'threading' backend
        log_probs = Parallel(n_jobs=self.n_jobs, backend='threading')(
            delayed(compute_total_log_prob_pois_logspace)(y_t, y_lags, rho, mu_t, self.max_j)
            for y_t, y_lags, rho, mu_t in obs_args
        )

        # Check for any NaN or infinite values in log_probs
        if np.any(~np.isfinite(log_probs)):
            return np.full_like(log_probs, np.inf)  # Assign infinity to invalid computations

        return -np.array(log_probs)  # Return negative log-likelihood

    def fit(self, start_params=None, maxiter=1000, maxfun=5000, method='lbfgs', verbose=1, **kwds):
        """
        Fit the Poisson INAR model using Maximum Likelihood Estimation.

        Parameters:
        - start_params (array-like, optional): Initial guess for the parameters.
        - maxiter (int, optional): Maximum number of iterations for the optimizer. Default is 1000.
        - maxfun (int, optional): Maximum number of function evaluations. Default is 5000.
        - method (str, optional): Optimization method to use. Default is 'lbfgs'.
        - verbose (int, optional): Verbosity level. Default is 1 (display progress).
        - **kwds: Additional keyword arguments for the optimizer.

        Returns:
        - PoissonINARResults: Fitted model results with named parameters.
        """
        num_beta = self.exog.shape[1]
        num_rho = self.p

        # Initialize start_params if not provided
        if start_params is None:
            start_beta = np.zeros(num_beta)  # Starting values for beta coefficients
            start_gamma = np.zeros(num_rho)  # Starting values for gamma parameters
            start_params = np.concatenate([start_beta, start_gamma])

        # Define bounds for the parameters (no bounds in this case; adjust as needed)
        bounds = [(None, None)] * len(start_params)  # Example: no bounds

        # Fit the model using the superclass's fit method
        mlefit = super(PoissonINAR, self).fit(
            start_params=start_params,
            maxiter=maxiter,
            maxfun=maxfun,
            method=method,  # Optimizer method (e.g., 'lbfgs')
            bounds=bounds,
            disp=verbose > 0,  # Display optimizer output if verbose > 0
            **kwds
        )

        # Create parameter names: exogenous variables + gamma parameters
        param_names = self.var_names + [f'gamma_{i+1}' for i in range(num_rho)]

        # Return the custom results object with named parameters
        return PoissonINARResults(self, mlefit, param_names)

    def predict_custom(self, params, exog=None, last_p_y=None, random_state=None):
        """
        Generate predictions using the fitted Poisson INAR model.

        This method performs stochastic prediction by simulating the thinning process and Poisson innovations.

        Parameters:
        - params (array-like): Fitted parameter vector [beta coefficients..., gamma1, gamma2, ..., gamma_p].
        - exog (array-like): Exogenous variables for prediction (must align with training exog).
        - last_p_y (array-like): List or array of the last p observed counts from the training data to initialize predictions.
        - random_state (int, optional): Seed for the random number generator to ensure reproducibility. Default is None.

        Returns:
        - np.ndarray: Array of predicted y values.
        """
        num_beta = self.exog.shape[1]
        beta = params[:num_beta]  # Extract beta coefficients
        gamma = params[num_beta:]  # Extract gamma parameters

        # Logistic transformation to obtain thinning probabilities
        rho = 1.0 / (1.0 + np.exp(-gamma))  # rho = [rho1, rho2, ..., rho_p]

        # Calculate Poisson means for the innovation term
        mu = np.exp(np.dot(exog, beta))  # mu = exp(X * beta)

        # Ensure that last_p_y is provided for initializing the lags
        if last_p_y is None:
            raise ValueError("last_p_y (last p y's from training data) must be provided for prediction.")

        last_p_y = list(last_p_y)  # Make a mutable copy
        y_pred = []  # List to store predicted counts

        # Initialize the random number generator if a seed is provided
        if random_state is not None:
            rng = np.random.default_rng(random_state)
        else:
            rng = np.random.default_rng()

        # Iterate over each exogenous observation to generate predictions
        for i in range(len(exog)):
            y_lags = last_p_y.copy()  # Current lagged counts
            mu_t = mu[i]  # Poisson mean for the innovation term

            # Perform stochastic thinning for each lag
            carried_over = 0
            for j in range(self.p):
                carried_over += rng.binomial(y_lags[j], rho[j])

            # Add the Poisson innovation
            y_t_pred = carried_over + rng.poisson(mu_t)
            y_pred.append(y_t_pred)

            # Update the lagged counts for the next prediction
            last_p_y.pop(0)
            last_p_y.append(y_t_pred)

        return np.array(y_pred)  # Return predictions as a NumPy array

# %%
# Define the regression formula (excluding lagged y's)
selected_exog_lagged_terms = [
    'output_lag_1',
    'strikes_percent_change_lag_1',
    'spike_lag_1',
    'zero_count_lag_1'
]
all_terms_inar = selected_exog_lagged_terms + fourier_terms
expr_poinar = 'strikes ~ ' + ' + '.join(all_terms_inar)

# Create design matrices using Patsy
y_train_poinar, X_train_poinar = dmatrices(expr_poinar, strikes_data_train, return_type='dataframe')
y_test_poinar, X_test_poinar = dmatrices(expr_poinar, strikes_data_test, return_type='dataframe')

# Print columns names
print("X_train_poinar columns:", X_train_poinar.columns)
print("y_train_poinar columns:", y_train_poinar.columns)
print("\n")

# Identify variables
exog_vars = ['Intercept'] + all_terms_inar
print("Exogenous Variables:", exog_vars)
print("\n")

# Initialize the Poisson INAR model
poinar_model = PoissonINAR(
    endog=y_train_poinar['strikes'].values,
    exog=X_train_poinar[exog_vars],  # Pass DataFrame to retain column names
    p=N,  # Specify the number of AR terms
    max_j=max_counts
)

# Fit the Poisson INAR model
poinar_results = poinar_model.fit(maxiter=10000)
print("\n")
print(poinar_results.summary())
# Out:
# X_train_poinar columns: Index(['Intercept', 'output_lag_1', 'strikes_percent_change_lag_1',
#        'spike_lag_1', 'zero_count_lag_1', 'sin_1', 'cos_1'],
#       dtype='object')
# y_train_poinar columns: Index(['strikes'], dtype='object')
#
#
# Exogenous Variables: ['Intercept', 'output_lag_1', 'strikes_percent_change_lag_1', 'spike_lag_1', 'zero_count_lag_1', 'sin_1', 'cos_1']
#
#
#
#
#                              PoissonINAR Results
# ==============================================================================
# Dep. Variable:                      y   Log-Likelihood:                -205.67
# Model:                    PoissonINAR   AIC:                             429.3
# Method:            Maximum Likelihood   BIC:                             451.2
# Date:                Sun, 24 Nov 2024
# Time:                        07:39:29
# No. Observations:                  84
# Df Residuals:                      77
# Df Model:                           6
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# Intercept                        0.9642      0.198      4.882      0.000       0.577       1.351
# output_lag_1                     1.9621      1.727      1.136      0.256      -1.424       5.348
# strikes_percent_change_lag_1    -0.0016      0.001     -1.332      0.183      -0.004       0.001
# spike_lag_1                     -0.0035      0.348     -0.010      0.992      -0.686       0.679
# zero_count_lag_1                 0.6150      0.398      1.547      0.122      -0.164       1.394
# sin_1                            0.3528      0.162      2.183      0.029       0.036       0.669
# cos_1                           -0.5471      0.134     -4.080      0.000      -0.810      -0.284
# gamma_1                         -1.7652      0.615     -2.868      0.004      -2.971      -0.559
# gamma_2                         -0.7015      0.332     -2.111      0.035      -1.353      -0.050
# ================================================================================================

# %% [markdown]
# # Information Criteria

# %%
# Initialize a list to hold evaluation metrics for each model
evaluation_metrics = []

# Compute AIC and BIC and append metrics to list for each model
evaluation_metrics.append({
    'Model': 'Poisson',
    'AIC': poisson_results.aic,
    'BIC': poisson_results.bic
})

evaluation_metrics.append({
    'Model': 'NegativeBinomial',
    'AIC': nb_results.aic,
    'BIC': nb_results.bic
})

evaluation_metrics.append({
    'Model': 'Poisson_INAR',
    'AIC': poinar_results.aic,
    'BIC': poinar_results.bic
})

# Create DataFrame from the list of dictionaries
evaluation_metrics_df = pd.DataFrame(evaluation_metrics)

# Display the DataFrame
display(evaluation_metrics_df)
# Out:
#               Model         AIC         BIC
# 0           Poisson  442.677793  474.278412
# 1  NegativeBinomial  437.408218  471.439654
# 2      Poisson_INAR  429.341216  451.218567

# %% [markdown]
# # Model Predictions

# %%
# Initialize a DataFrame to store predictions
predictions_df = pd.DataFrame(index=strikes_data_test.index)
predictions_df['Time'] = strikes_data_test['date'].values
predictions_df['Actual'] = strikes_data_test['strikes'].values

# %%
# Predictions from Poisson regression
poisson_pred = poisson_results.predict(X_test_poisson)
poisson_pred_rounded = np.round(poisson_pred).astype(int)
predictions_df['Poisson'] = poisson_pred_rounded.values.astype('float').round()

# %%
# Predictions from Negative Binomial regression
nb_pred = nb_results.predict(X_test_nb)
nb_pred_rounded = np.round(nb_pred).astype(int)
predictions_df['NegativeBinomial'] = nb_pred_rounded.values.astype('float').round()

# %%
# For Poisson INAR
last_p_y_poinar = strikes_data_train['strikes'].iloc[-N:].values

# Generate predictions using the Poisson INAR Model
poinar_predictions = poinar_model.predict_custom(
    params=poinar_results.params,
    exog=X_test_poinar[exog_vars].values,
    last_p_y=last_p_y_poinar
)

# Add predictions to the DataFrame
predictions_df['Poisson_INAR'] = poinar_predictions.astype('float').round()

# %%
# Display the predictions DataFrame
display(predictions_df)
# Out:
#           Time  Actual  Poisson  NegativeBinomial  Poisson_INAR
# 84  1975-04-01       2      4.0               4.0           9.0
# 85  1975-05-01       1      5.0               5.0           6.0
# 86  1975-06-01       2      4.0               4.0          11.0
# 87  1975-07-01       2      4.0               4.0           6.0
# 88  1975-08-01       3      3.0               3.0           5.0
# 89  1975-09-01       0      3.0               3.0           6.0
# 90  1975-10-01       5      3.0               3.0           7.0
# 91  1975-11-01       5      3.0               3.0           3.0
# 92  1975-12-01       1      3.0               3.0           1.0
# 93  1976-01-01       1      3.0               3.0           0.0
# 94  1976-02-01       1      3.0               3.0           2.0
# 95  1976-03-01       1      3.0               3.0           2.0
# 96  1976-04-01       8      4.0               4.0           9.0
# 97  1976-05-01       5      4.0               4.0           4.0
# 98  1976-06-01       9      5.0               5.0           9.0
# 99  1976-07-01       6      9.0               9.0           6.0
# 100 1976-08-01       3      8.0               8.0           6.0
# 101 1976-09-01       4      5.0               5.0           5.0
# 102 1976-10-01       6      2.0               2.0           7.0
# 103 1976-11-01       2      4.0               4.0           5.0
# 104 1976-12-01       3      3.0               3.0           8.0

# %%
# Helper function to calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    # To avoid division by zero
    non_zero = y_true != 0
    return np.mean(np.abs((y_true[non_zero] - y_pred[non_zero]) / y_true[non_zero])) * 100

# %%
# Helper function to calculate sMAPE
def symmetric_mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2.0
    non_zero = denominator != 0
    return np.mean(np.abs(y_true[non_zero] - y_pred[non_zero]) / denominator[non_zero]) * 100

# %%
# Initialize a dictionary to store metrics
metrics_dict = {
    'Model': [],
    'MSE': [],
    'RMSE': [],
    'MAE': [],
    'MAPE': [],
    'sMAPE': []
}

# Calculate metrics for each model
models = ['Poisson', 'NegativeBinomial', 'Poisson_INAR']
for model in models:
    y_pred = predictions_df[model]
    y_true = predictions_df['Actual']

    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    mape = mean_absolute_percentage_error(y_true, y_pred)
    smape = symmetric_mean_absolute_percentage_error(y_true, y_pred)

    metrics_dict['Model'].append(model)
    metrics_dict['MSE'].append(mse)
    metrics_dict['RMSE'].append(rmse)
    metrics_dict['MAE'].append(mae)
    metrics_dict['MAPE'].append(mape)
    metrics_dict['sMAPE'].append(smape)

# Create a DataFrame
metrics_df = pd.DataFrame(metrics_dict)
display(metrics_df)
# Out:
#               Model        MSE      RMSE       MAE        MAPE      sMAPE
# 0           Poisson   7.095238  2.663689  2.333333  105.138889  71.388717
# 1  NegativeBinomial   7.095238  2.663689  2.333333  105.138889  71.388717
# 2      Poisson_INAR  12.809524  3.579040  2.619048  121.875000  70.959137

# %%
# Plot grouped bar chart
metrics_to_plot = ['RMSE', 'MAE']
x = np.arange(len(models))  # Label locations
width = 0.25  # Width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
for i, metric in enumerate(metrics_to_plot):
    ax.bar(x + i * width, metrics_df[metric], width, label=metric)
    # Add metric value labels above the bars
    for j in range(len(models)):
        ax.text(x[j] + i * width, metrics_df[metric][j] + 0.01, f'{metrics_df[metric][j]:.2f}',
                ha='center', va='bottom', fontsize=10)

# Set axis labels and title
ax.set_xlabel('Model')
ax.set_ylabel('Metric Value')
ax.set_title('Model Metrics Comparison (RMSE, MAE, SMAPE)')
ax.set_xticks(x + (width * (len(metrics_to_plot) - 1)) / 2)
ax.set_xticklabels(models)
ax.legend()

plt.tight_layout()
plt.show()

# %%
# Plot actual vs. predicted values
model_names = ['Poisson', 'NegativeBinomial', 'Poisson_INAR']
for model in model_names:
    plt.figure(figsize=(12, 6))
    plt.plot(predictions_df['Time'], predictions_df['Actual'], 'ro-', label='Actual Strikes')
    plt.plot(predictions_df['Time'], predictions_df[model], 'bo-', label=f'Predicted ({model})')
    plt.title(f'Actual vs. Predicted Strike Counts ({model})')
    plt.xlabel('Date')
    plt.ylabel('Number of Strikes')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
    print("\n")
