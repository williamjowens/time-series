# %% [markdown]
# # Imports

# %%
import math
import copy
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, Dataset, DataLoader, Subset
from torch import Tensor
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from typing import Tuple, Optional

torch.set_default_dtype(torch.float32)

# %% [markdown]
# # RBF Kernel

# %%
# RBF kernel with learnable hyperparameters and jitter
def rbf_kernel(
        x1: torch.Tensor,
        x2: torch.Tensor,
        lengthscale: float,
        variance: float,
        jitter: float = 1e-6
    ) -> torch.Tensor:
    """
    Radial Basis Function (RBF) kernel with learnable log-hyperparameters and jitter.
    k(x, x') = variance * exp(-0.5 * ||x - x'||^2 / lengthscale^2)
    """
    diff = x1.unsqueeze(1) - x2.unsqueeze(0)  # [N, M, D]
    K = variance * torch.exp(-0.5 * (diff**2).sum(-1) / lengthscale**2)  # [N, M]

    # Add jitter on the diagonal when x1 == x2
    if x1.shape == x2.shape and torch.allclose(x1, x2):
        K = K + jitter * torch.eye(x1.size(0), device=K.device, dtype=K.dtype)

    return K

# %% [markdown]
# # Sparse GP Class

# %%
# Sparse GP Transition Model
class SparseGP(nn.Module):
    """
    Sparse, mean-field variational GP for the transition:
      q(u_d) = N(m_d, S_d),  p(u_d) = N(mean(Z), Kzz)
    Posterior predictive:
      mu_d(x) = mean_d(x) + k(x,Z) Kzz^{-1} (m_d - mean_d(Z))
      var_d(x) = k(x,x) - k(x,Z) Kzz^{-1} [Kzz - S_d] Kzz^{-1} k(Z,x)
    """
    def __init__(self, Z: torch.Tensor, state_dim: int):
        super().__init__()
        self.Z = Z
        self.M, self.input_dim = Z.shape
        self.state_dim = state_dim

        # Learnable GP hyperparameters: log-lengthscale and log-variance
        self.log_ls = nn.Parameter(torch.zeros(()))
        self.log_var = nn.Parameter(torch.zeros(()))

        # Variational parameters; set in init_variational
        self.m = None  # [D, M]
        self.S = None  # [D, M, M]

    def init_variational(self, D: int):
        """Initialize q(u_d)=N(m_d, S_d) with S_d = Kzz."""
        self.m = nn.Parameter(torch.zeros(D, self.M))
        with torch.no_grad():
            Kzz = rbf_kernel(
                self.Z,
                self.Z,
                self.log_ls.exp(),
                self.log_var.exp()
            )
        S0 = Kzz.unsqueeze(0).repeat(D, 1, 1)
        self.S = nn.Parameter(S0)

    def prior_Kzz(self) -> torch.Tensor:
        """Compute the prior covariance Kzz = k(Z, Z)."""
        return rbf_kernel(
            self.Z,
            self.Z,
            self.log_ls.exp(),
            self.log_var.exp()
        )

    def kl_U(self) -> torch.Tensor:
        """
        KL[q(U) || p(U)] summed over output dimensions.
        p(u_d)=N(mean(Z), Kzz), mean_d(Z)=Z[:, d].
        """
        Kzz = self.prior_Kzz()   # [M, M]
        Ki = torch.inverse(Kzz)  # [M, M]
        logdet_K = torch.logdet(Kzz)
        D = self.m.size(0)

        # Mean(Z): [D, M], each row d = Z[:, d]
        meanZ = self.Z[:, :self.state_dim].t()  # [D, M]

        kl = 0.0
        for d in range(D):
            md, Sd = self.m[d], self.S[d]  # md:[M], Sd:[M,M]
            trace_term = torch.trace(Ki @ Sd)
            quad_term = (md - meanZ[d]) @ (Ki @ (md - meanZ[d]))
            logdet_S = torch.logdet(Sd)
            kl += 0.5 * (trace_term + quad_term - self.M + logdet_K - logdet_S)
        return kl

    def predict_f(
            self,
            x: torch.Tensor
        ) -> Tuple[torch.Tensor, torch.Tensor]:
        """
        Posterior predictive mean and variance at inputs x.
        Args:
          x: [B, input_dim]
        Returns:
          mu:  [B, D]
          var: [B, D]
        """
        B = x.size(0)
        D = self.m.size(0)
        sigma_f2 = self.log_var.exp()
        ls = self.log_ls.exp()

        Kzz = self.prior_Kzz()
        Ki = torch.inverse(Kzz)
        Kxz = rbf_kernel(x, self.Z, ls, sigma_f2)  # [B, M]

        meanX = x[:, :self.state_dim]              # [B, D]
        meanZ = self.Z[:, :self.state_dim].t()     # [D, M]

        mu = torch.zeros(B, D, dtype=x.dtype, device=x.device)
        var = torch.zeros(B, D, dtype=x.dtype, device=x.device)

        for d in range(D):
            md, Sd = self.m[d], self.S[d]
            mu[:, d] = meanX[:, d] + Kxz @ (Ki @ (md - meanZ[d]))
            kxx = sigma_f2 * torch.ones(B, dtype=x.dtype, device=x.device)
            tmp = Ki @ (Kzz - Sd) @ Ki
            var[:, d] = kxx - torch.sum((Kxz @ tmp) * Kxz, dim=1)

        # Clamp for stability
        var = var.clamp(min=1e-6)
        return mu, var

# %% [markdown]
# # Recognition Network

# %%
# Recognition Network for q(X)
class RecognitionNet(nn.Module):
    """
    Bidirectional GRU -> parameters of q(x0), q(xt | x_{t-1}):
      q(x0)=N(m0, L0 L0^T),  q(xt|x_{t-1})=N(A_t x_{t-1}, L_t L_t^T)
    """
    def __init__(
            self,
            obs_dim: int,
            act_dim: int,
            hid_dim: int,
            state_dim: int
        ):
        super().__init__()
        self.state_dim = state_dim
        self.rnn = nn.GRU(
            obs_dim + act_dim,
            hid_dim,
            batch_first=True,
            bidirectional=True
        )
        D = state_dim
        self.lin_A = nn.Linear(2 * hid_dim, D * D)
        self.lin_L = nn.Linear(2 * hid_dim, D * (D + 1) // 2)
        self.lin_m0 = nn.Linear(hid_dim, D)
        self.lin_L0 = nn.Linear(hid_dim, D * (D + 1) // 2)

    def forward(self, y: torch.Tensor, a: torch.Tensor):
        """
        Encode observations+actions -> {m0, L0}, {A_t, L_t}.

        Args:
          y: [B, T, obs_dim]
          a: [B, T, act_dim]
        Returns:
          m0:   [B, D]
          L0_f: [B, D*(D+1)//2]
          A:    [B, T, D, D]
          L_f:  [B, T, D*(D+1)//2]
        """
        B, T, _ = y.shape
        inp = torch.cat([y, a], dim=-1)       # [B, T, obs+act]
        H, h_n = self.rnn(inp)                # H:[B,T,2H], h_n:[2,B,H]

        D = self.state_dim
        A_flat = self.lin_A(H).view(B, T, D, D)
        L_flat = self.lin_L(H)                # [B, T, D*(D+1)//2]

        # Backward final hidden -> x0 params
        h_back = h_n[1]                       # [B, H]
        m0 = self.lin_m0(h_back)              # [B, D]
        L0_f = self.lin_L0(h_back)            # [B, D*(D+1)//2]

        return m0, L0_f, A_flat, L_flat

# %%
def flat_to_lower(Lf: torch.Tensor, D: int) -> torch.Tensor:
    """
    Out-of-place conversion of flat triangular entries to a lower-triangular matrix L.
    Lf: [N, M] where M = D*(D+1)//2
    Returns L: [N, D, D], with diag entries softplus’d.
    """
    # Lf is shape [N, M]
    N, M = Lf.shape
    device, dtype = Lf.device, Lf.dtype

    # Tril indices once
    idx0, idx1 = torch.tril_indices(D, D, device=device)
    # Compute linear indices into a (D*D) vector
    lin_idx = idx0 * D + idx1  # [M]
    lin_idx = lin_idx.unsqueeze(0).expand(N, -1)  # [N, M]

    # Start with a flat [N, D*D] zero tensor
    out_flat = torch.zeros(N, D*D, device=device, dtype=dtype)
    # Scatter Lf into the lower-triangular positions
    out_flat = out_flat.scatter(1, lin_idx, Lf)

    # Apply softplus to the diagonal entries
    # Diagonal linear indices are 0, D+1, 2(D+1), ..., (D-1)(D+1)
    diag_idx = torch.arange(0, D*D, D+1, device=device)
    diag_idx = diag_idx.unsqueeze(0).expand(N, -1)  # [N, D]
    # Gather current diag
    diag_vals = out_flat.gather(1, diag_idx)        # [N, D]
    # Softplus
    diag_sp = torch.nn.functional.softplus(diag_vals)
    # Scatter them back
    out_flat = out_flat.scatter(1, diag_idx, diag_sp)

    # Reshape into [N, D, D]
    return out_flat.view(N, D, D)

# %% [markdown]
# # GPSSM Class

# %%
# GPSSM Model and Exact ELBO
class GPSSM(nn.Module):
    """
    Full GPSSM model:
      - SparseGP transition
      - RecognitionNet posterior
      - Exact ELBO: KL[u], KL[x0], H[q(X)], E[log p(y|x)], E[log p(x|f)]
    """
    def __init__(
            self,
            obs_dim: int,
            act_dim: int,
            state_dim: int,
            hid_dim: int,
            Z: torch.Tensor,
            num_mc_samples: int = 1
        ):
        super().__init__()
        self.state_dim = state_dim
        self.num_mc = num_mc_samples

        # (1) Sparse GP transition
        self.gp = SparseGP(Z, state_dim)
        self.gp.init_variational(state_dim)

        # (2) Recognition network q(X)
        self.rec = RecognitionNet(obs_dim, act_dim, hid_dim, state_dim)

        # (3) Observation model p(y_t|x_t)=N(Wg x_t + bg, sigma_g2 I)
        self.Wg = nn.Linear(state_dim, obs_dim, bias=True)
        self.log_sigma_g2 = nn.Parameter(torch.zeros(()))

    def elbo(self, y: torch.Tensor, a: torch.Tensor) -> torch.Tensor:
        """
        Compute one-sample ELBO estimate:
            ELBO = Eq_x0 + H[q(X)] - KL[q(U)||p(U)]
                 + E_q[log p(y|x)] + E_q[log p(x|f)]
        Returns:
            ELBO averaged over batch
        """
        B, T, _ = y.shape
        D = self.state_dim

        # Unpack q(X)
        m0, L0_f, A, L_f = self.rec(y, a)
        L0 = flat_to_lower(L0_f, D)                    # [B, D, D]
        Lt = flat_to_lower(L_f.reshape(B * T, -1), D)  # [B*T, D, D]
        Lt = Lt.reshape(B, T, D, D).contiguous()       # Break any strides

        # KL over GP inducing points (U)
        kl_u = self.gp.kl_U()

        # KL over initial state q(x0)||p(x0)=N(0,I)
        Sigma0 = L0 @ L0.transpose(-1, -2)               # [B, D, D]
        tr0 = Sigma0.diagonal(dim1=-2, dim2=-1).sum(-1)  # [B]
        ld0 = torch.logdet(Sigma0 + 1e-6*torch.eye(D, device=Sigma0.device))  # [B]
        m0norm2 = (m0**2).sum(-1)                        # [B]
        kl_x0 = 0.5 * torch.sum(tr0 + m0norm2 - D - ld0)

        # Entropy H[q(X)]
        H_const = 0.5 * (T + 1) * D * math.log(2*math.pi*math.e)
        # Vectorised log-dets of LtLt^T
        Lt_flat = Lt.reshape(B*T, D, D)
        SigmaL = Lt_flat @ Lt_flat.transpose(-1, -2)   # [B*T, D, D]
        ld_Lt = torch.logdet(SigmaL)                   # [B*T]
        ld_Lt_bt = ld_Lt.reshape(B, T)                 # [B, T]
        # Assemble entropy
        H_term = H_const + 0.5 * torch.sum(ld0.unsqueeze(-1) + ld_Lt_bt)

        # Observation term E_q[log p(y|x)]
        sigma_g2 = torch.exp(self.log_sigma_g2)
        m_t, S_t = m0, Sigma0
        Ey_terms = []
        for t in range(T):
            mu_y = self.Wg(m_t)
            cov  = (
                self.Wg.weight @ S_t @ self.Wg.weight.t()
                + sigma_g2 * torch.eye(
                    mu_y.size(-1),
                    dtype=mu_y.dtype,
                    device=mu_y.device
                )
            )
            diff = (y[:,t] - mu_y).unsqueeze(-1)  # [B,1,1]
            Ey = -0.5 * torch.sum(
                diff.transpose(-1,-2) @ torch.inverse(cov) @ diff
                + torch.logdet(2*torch.pi*cov),
                dim=(1, 2)
            )  # [B]
            Ey_terms.append(Ey)
            # Propagate forward
            m_t = (A[:,t] @ m_t.unsqueeze(-1)).squeeze(-1)
            S_t = (A[:,t] @ S_t @ A[:,t].transpose(-1,-2)
                + Lt[:,t] @ Lt[:,t].transpose(-1,-2))
        E_logy = torch.sum(torch.stack(Ey_terms))  # scalar

        # Transition term (MC)
        trans_samples = []
        for _ in range(self.num_mc):
            eps0 = torch.randn(B, D, 1, dtype=y.dtype, device=y.device)
            x_prev = m0.unsqueeze(-1) + L0 @ eps0
            lp_list = []
            for t in range(T):
                inp = torch.cat([x_prev.squeeze(-1), a[:,t]], dim=-1)
                mu_f, var_f = self.gp.predict_f(inp)  # [B,D]
                mu_f, var_f = mu_f.unsqueeze(-1), var_f.unsqueeze(-1)
                eps = torch.randn_like(var_f)
                x_lin = A[:,t] @ x_prev
                x_t = x_lin + Lt[:,t] @ eps
                diff2 = (x_t - mu_f)**2
                lp = 0.5 * torch.sum(
                    -diff2/var_f
                    - torch.log(2*torch.pi*var_f),
                    dim=(1, 2)
                )  # [B]
                lp_list.append(lp)
                x_prev = x_t
            trans_samples.append(torch.sum(torch.stack(lp_list)))
        trans = torch.mean(torch.stack(trans_samples))  # scalar

        # Combine all terms
        elbo = -kl_u - kl_x0 + H_term + E_logy + trans
        return elbo / B

    def forward(self, y: torch.Tensor, a: torch.Tensor) -> torch.Tensor:
        """Negative ELBO (for minimisation)."""
        return -self.elbo(y, a)

    def forecast(
            self,
            y_obs: torch.Tensor,
            a_obs: torch.Tensor = None,
            horizon: int = 30,
            actions_future: torch.Tensor = None,
            use_map: bool = True,
            num_samples: int = 1
        ):
        """
        Forecast future y for `horizon` steps given observed window (y_obs, a_obs).
        If num_samples>1 and use_map=False, draws multiple sample trajectories
        and averages their means and variances.

        Returns:
            y_means: [horizon, obs_dim]
            y_vars: [horizon, obs_dim]
        """
        B, T, _ = y_obs.shape

        # Default zeros if no actions
        if a_obs is None:
            a_obs = torch.zeros(
                B, T,
                self.gp.input_dim - self.state_dim,
                dtype=y_obs.dtype,
                device=y_obs.device
            )
        if actions_future is None:
            actions_future = torch.zeros(
                B, horizon,
                self.gp.input_dim - self.state_dim,
                dtype=y_obs.dtype,
                device=y_obs.device
            )

        # Infer q(x_T)
        m0, L0_f, A, L_f = self.rec(y_obs, a_obs)
        L0 = flat_to_lower(L0_f, self.state_dim)
        Lt = flat_to_lower(
            L_f.view(B * T, -1),
            self.state_dim
        ).view(
            B, T,
            self.state_dim,
            self.state_dim
        )

        # Propagate to get posterior at t = T
        m_t = m0
        Sigma_t = L0 @ L0.transpose(-1, -2)
        for t in range(T):
            m_t = (A[:, t] @ m_t.unsqueeze(-1)).squeeze(-1)
            Sigma_t = (
                A[:, t] @ Sigma_t @ A[:, t].transpose(-1, -2)
                + Lt[:, t] @ Lt[:, t].transpose(-1, -2)
            )

        # Draw num_samples rollouts
        means_list = []
        vars_list = []
        for _ in range(num_samples):
            x_mean, x_cov = m_t, Sigma_t
            y_means = []
            y_vars = []
            for h in range(horizon):
                u = actions_future[:, h, :]
                inp = torch.cat([x_mean, u], dim=-1)
                mu_f, var_f = self.gp.predict_f(inp)
                if use_map:
                    x_mean, x_cov = mu_f, torch.diag_embed(var_f)
                else:
                    eps = torch.randn_like(mu_f)
                    x_mean = mu_f + torch.sqrt(var_f) * eps
                    x_cov = torch.diag_embed(var_f)

                y_mean = self.Wg(x_mean)
                y_cov = (
                    self.Wg.weight @ x_cov @ self.Wg.weight.t()
                    + torch.exp(self.log_sigma_g2) *
                    torch.eye(
                        y_mean.size(-1),
                        device=y_mean.device
                    )
                )
                y_means.append(y_mean.squeeze(0))
                y_vars.append(
                    torch.diagonal(
                        y_cov,
                        dim1=-2,
                        dim2=-1
                    ).squeeze(0)
                )
            means_list.append(torch.stack(y_means))  # [horizon, obs_dim]
            vars_list.append(torch.stack(y_vars))

        # Aggregate across samples
        means_all = torch.stack(means_list)  # [num_samples, horizon, obs_dim]
        vars_all = torch.stack(vars_list)
        y_means = means_all.mean(0)
        y_vars = vars_all.mean(0)

        return y_means, y_vars

# %% [markdown]
# # Training Utility

# %%
# Training utility
def train(
        model: GPSSM,
        train_loader: DataLoader,
        val_loader: Optional[DataLoader] = None,
        lr: float = 1e-3,
        epochs: int = 100
    ):
    """
    Train GPSSM by minimizing NELBO, snapshotting the parameters
    from the epoch with lowest validation NELBO (if val_loader provided),
    otherwise lowest training NELBO.
    """
    opt = optim.Adam(model.parameters(), lr=lr)
    best_loss = float('inf')
    best_params = None
    best_epoch = -1

    for ep in range(1, epochs+1):
        # Training step
        model.train()
        train_sum = 0.0
        for yb, ab in train_loader:
            loss = model(yb, ab)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            opt.step()
            train_sum += loss.item() * yb.size(0)
        train_nelbo = train_sum / len(train_loader.dataset)

        # Evaluation step
        eval_loader = val_loader if val_loader is not None else train_loader
        model.eval()
        eval_sum = 0.0
        with torch.no_grad():
            for yb, ab in eval_loader:
                eval_sum += model(yb, ab).item() * yb.size(0)
        eval_nelbo = eval_sum / len(eval_loader.dataset)

        msg = f"Epoch {ep:03d} | train NELBO = {train_nelbo:.4f}"
        if val_loader is not None:
            msg += f" | val NELBO = {eval_nelbo:.4f}"
        print(msg)

        # Snapshot best
        current = eval_nelbo if val_loader is not None else train_nelbo
        if current < best_loss:
            best_loss = current
            best_epoch = ep
            best_params = copy.deepcopy(model.state_dict())

    # Restore best
    model.load_state_dict(best_params)
    print(f"Restored parameters from epoch {best_epoch} (NELBO={best_loss:.4f})")
    return model

# %% [markdown]
# # Time Series Demo

# %%
# Generate a noisy sine wave
T_total = 300
t = np.arange(T_total)
series = np.sin(0.05 * t) + 0.1 * np.random.randn(T_total)

# Parameters
window = 50
horizon = 30

# %%
# Split into train / val windows

# train: first 200 points (0–200)
train_series = series[:4*window]

# val: next 50 points (200–250)
val_series = series[4*window : 5*window]

# test true: the 30 points after val (250–280)
test_true = series[5*window : 5*window + horizon]

# %%
# Convert to tensors
train_y = torch.from_numpy(train_series) \
               .unsqueeze(0).unsqueeze(-1) \
               .float()  # [1, 200, 1]
train_a = torch.zeros(1, train_y.shape[1], 0).float()

val_y = torch.from_numpy(val_series) \
               .unsqueeze(0).unsqueeze(-1) \
               .float()  # [1,  50, 1]
val_a = torch.zeros(1, val_y.shape[1], 0).float()

# %%
# DataLoaders
train_loader = DataLoader(
    TensorDataset(train_y, train_a),
    batch_size=1,
    shuffle=False
)

val_loader = DataLoader(
    TensorDataset(val_y, val_a),
    batch_size=1,
    shuffle=False
)

# %%
# Instantiate GPSSM
obs_dim, act_dim, state_dim = 1, 0, 4
hid_dim = 20
M = 20
Z = torch.randn(M, state_dim).float()

model = GPSSM(
    obs_dim=obs_dim,
    act_dim=act_dim,
    state_dim=state_dim,
    hid_dim=hid_dim,
    Z=Z,
    num_mc_samples=3
)

# %%
# Train with validation
model = train(
    model,
    train_loader,
    val_loader,
    lr=1e-3,
    epochs=300,
)
# Out:
# Epoch 001 | train NELBO = 835.9987 | val NELBO = 242.6410
# Epoch 002 | train NELBO = 843.6524 | val NELBO = 236.9418
# Epoch 003 | train NELBO = 800.7302 | val NELBO = 232.2067
# Epoch 004 | train NELBO = 807.7596 | val NELBO = 214.9899
# Epoch 005 | train NELBO = 770.2499 | val NELBO = 215.9494
# Epoch 006 | train NELBO = 787.6622 | val NELBO = 224.9514
# Epoch 007 | train NELBO = 765.4750 | val NELBO = 216.1432
# Epoch 008 | train NELBO = 759.9843 | val NELBO = 225.5307
# Epoch 009 | train NELBO = 722.9502 | val NELBO = 223.6324
# Epoch 010 | train NELBO = 738.0569 | val NELBO = 217.2970
# Epoch 011 | train NELBO = 716.2693 | val NELBO = 216.6216
# Epoch 012 | train NELBO = 727.4716 | val NELBO = 203.8310
# Epoch 013 | train NELBO = 708.3810 | val NELBO = 207.2964
# Epoch 059 | train NELBO = 244.7848 | val NELBO = 106.0721
# Epoch 060 | train NELBO = 235.4830 | val NELBO = 100.8648
# Epoch 061 | train NELBO = 215.4810 | val NELBO = 99.2971
# Epoch 062 | train NELBO = 184.9377 | val NELBO = 93.9766
# Epoch 063 | train NELBO = 181.8600 | val NELBO = 81.3458
# Epoch 064 | train NELBO = 135.3963 | val NELBO = 89.2987
# Epoch 065 | train NELBO = 156.6873 | val NELBO = 64.9628
# Epoch 066 | train NELBO = 132.1087 | val NELBO = 68.0216
# Epoch 067 | train NELBO = 88.9497 | val NELBO = 55.2209
# Epoch 068 | train NELBO = 79.7812 | val NELBO = 51.4181
# Epoch 069 | train NELBO = 66.0885 | val NELBO = 57.1049
# Epoch 070 | train NELBO = 50.5367 | val NELBO = 35.5615
# Epoch 071 | train NELBO = 20.4357 | val NELBO = 39.5127
# Epoch 072 | train NELBO = -0.9863 | val NELBO = 29.0250
# Epoch 073 | train NELBO = -25.6293 | val NELBO = 32.9409
# Epoch 074 | train NELBO = -28.8567 | val NELBO = 20.7854
# Epoch 075 | train NELBO = -39.5519 | val NELBO = 24.6676
# Epoch 076 | train NELBO = -72.8395 | val NELBO = 4.4873
# Epoch 077 | train NELBO = -105.2043 | val NELBO = 13.2295
# Epoch 078 | train NELBO = -90.9984 | val NELBO = 6.0646
# Epoch 079 | train NELBO = -112.9882 | val NELBO = -8.7343
# Epoch 080 | train NELBO = -123.1775 | val NELBO = -5.3096
# Epoch 081 | train NELBO = -134.5948 | val NELBO = -21.0367
# Epoch 082 | train NELBO = -160.4369 | val NELBO = -16.9348
# Epoch 083 | train NELBO = -164.4393 | val NELBO = -21.0291
# Epoch 084 | train NELBO = -179.7164 | val NELBO = -29.4310
# Epoch 085 | train NELBO = -181.7699 | val NELBO = -21.6037
# Epoch 086 | train NELBO = -211.7909 | val NELBO = -16.8033
# Epoch 087 | train NELBO = -233.4462 | val NELBO = -38.2346
# Epoch 088 | train NELBO = -258.2032 | val NELBO = -34.9934
# Epoch 089 | train NELBO = -271.1840 | val NELBO = -29.1519
# Epoch 090 | train NELBO = -285.8185 | val NELBO = -46.4682
# Epoch 091 | train NELBO = -263.4152 | val NELBO = -45.3308
# Epoch 092 | train NELBO = -307.0142 | val NELBO = -56.9039
# Epoch 093 | train NELBO = -309.2728 | val NELBO = -62.6967
# Epoch 094 | train NELBO = -326.0957 | val NELBO = -63.6614
# Epoch 095 | train NELBO = -326.9210 | val NELBO = -67.9876
# Epoch 096 | train NELBO = -345.1853 | val NELBO = -65.6454
# Epoch 097 | train NELBO = -359.8240 | val NELBO = -74.2893
# Epoch 098 | train NELBO = -370.3589 | val NELBO = -66.8588
# Epoch 099 | train NELBO = -383.6547 | val NELBO = -83.8103
# Epoch 100 | train NELBO = -374.4211 | val NELBO = -77.8888
# Epoch 101 | train NELBO = -386.6490 | val NELBO = -91.0082
# Epoch 102 | train NELBO = -414.7297 | val NELBO = -88.9908
# Epoch 103 | train NELBO = -391.7379 | val NELBO = -83.6996
# Epoch 282 | train NELBO = 154564.4375 | val NELBO = 191547.7500
# Epoch 283 | train NELBO = 350464.0625 | val NELBO = -272.2218
# Epoch 284 | train NELBO = 1103275.5000 | val NELBO = -277.8614
# Epoch 285 | train NELBO = -990.7401 | val NELBO = -267.2469
# Epoch 286 | train NELBO = -954.3715 | val NELBO = -266.0327
# Epoch 287 | train NELBO = 325946.3750 | val NELBO = -242.5277
# Epoch 288 | train NELBO = 732166.6250 | val NELBO = 26776.8945
# Epoch 289 | train NELBO = 798179.6250 | val NELBO = -251.6556
# Epoch 290 | train NELBO = 64098.5781 | val NELBO = -240.8692
# Epoch 291 | train NELBO = 122027.3984 | val NELBO = -262.2955
# Epoch 292 | train NELBO = -972.8856 | val NELBO = -273.7337
# Epoch 293 | train NELBO = 857181.3125 | val NELBO = -230.3695
# Epoch 294 | train NELBO = 16866.6973 | val NELBO = -269.0123
# Epoch 295 | train NELBO = -967.4351 | val NELBO = -263.5248
# Epoch 296 | train NELBO = 320764.4062 | val NELBO = -273.6151
# Epoch 297 | train NELBO = -985.0041 | val NELBO = -248.0043
# Epoch 298 | train NELBO = 259326.5469 | val NELBO = -275.0921
# Epoch 299 | train NELBO = 8318.7451 | val NELBO = -292.5556
# Epoch 300 | train NELBO = -984.0916 | val NELBO = -279.2412
# Restored parameters from epoch 261 (NELBO=-296.5776)

# %%
# Forecast on the holdout test window
y_obs = torch.from_numpy(val_series) \
              .unsqueeze(0).unsqueeze(-1) \
              .float()  # [1, 50, 1]

# Rollout beyond val
y_pred, y_var = model.forecast(
    y_obs,
    horizon=horizon,
    use_map=False,
    num_samples=50
)

y_pred = y_pred.detach().numpy().flatten()
y_std = np.sqrt(y_var.detach().numpy().flatten())

# %%
# Plot train+val, true test, and forecasts
plt.figure(figsize=(8, 4))
# Plot everything up to 250
plt.plot(
    np.arange(5*window),
    series[:5*window],
    label="Train+Val Observed"
)
# True test
t_test = np.arange(5*window, 5*window+horizon)
plt.plot(t_test, test_true, '--k', label="True Test")
# Forecast mean + 95% CI
plt.plot(t_test, y_pred, 'r', label="Forecast")
plt.fill_between(
    t_test,
    y_pred - 1.96*y_std,
    y_pred + 1.96*y_std,
    color='r',
    alpha=0.2
)
plt.axvline(5*window, color='grey', linestyle=':')
plt.legend()
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("GPSSM: Train/Val/Test Forecast")
plt.tight_layout()
plt.show()

# %%
# Compute Test RMSE
rmse = np.sqrt(np.mean((y_pred - test_true)**2))
print(f"Test RMSE over horizon of {horizon} timesteps: {rmse:.4f}")
# Out:
# Test RMSE over horizon of 30 timesteps: 0.4442

# %% [markdown]
# # Actuator Demo

# %%
# Download and display the actuator dataset
df = pd.read_csv(
    "https://ftp.esat.kuleuven.be/pub/SISTA/data/mechanical/robot_arm.dat.gz",
    compression="gzip",
    sep=r"\s+",
    header=None,
    names=["u", "y"],
)

print(df.shape)
display(df.head())
# Out:
# (1024, 2)
#           u         y
# 0  0.221832 -0.177036
# 1  0.039028 -0.114708
# 2 -0.050296 -0.017258
# 3  0.008539  0.073361
# 4  0.072431  0.128063

# %%
# Normalize the data
u_raw = df["u"].values  # Measured reaction torque of the arm's mounting structure
y_raw = df["y"].values  # Resulting acceleration of the flexible arm

u_mu, u_sd = u_raw.mean(), u_raw.std()
y_mu, y_sd = y_raw.mean(), y_raw.std()
u = (u_raw - u_mu) / u_sd
y = (y_raw - y_mu) / y_sd

# %%
class ActuatorDataset(Dataset):
    def __init__(self, u, y, window):
        self.u = torch.from_numpy(u).float().unsqueeze(-1)
        self.y = torch.from_numpy(y).float().unsqueeze(-1)
        self.window = window

    def __len__(self):
        return len(self.y) - self.window

    def __getitem__(self, idx):
        y_seq = self.y[idx : idx + self.window]
        u_seq = self.u[idx : idx + self.window]
        return y_seq, u_seq

# %%
# Create sliding-window dataset
window = 50
horizon = 30

full_ds = ActuatorDataset(u, y, window)

# %%
# Train/validation/test split
n = len(full_ds)
n_train = int(0.7 * n)
n_val = int(0.15 * n)
train_ds = Subset(full_ds, range(0, n_train))
val_ds = Subset(full_ds, range(n_train, n_train + n_val))

# %%
# DataLoaders
batch_size = 16
train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

# %%
# Instantiate GPSSM
obs_dim = 1
act_dim = 1
state_dim = 4
hid_dim = 20
M = 30

Z = torch.randn(M, state_dim + act_dim)
model = GPSSM(
    obs_dim=obs_dim,
    act_dim=act_dim,
    state_dim=state_dim,
    hid_dim=hid_dim,
    Z=Z,
    num_mc_samples=8
)

# %%
# Train with validation checkpointing
model = train(
    model,
    train_loader,
    val_loader,
    lr=1e-3,
    epochs=300
)

# Extract the final context window for forecasting
y_obs, u_obs = full_ds[n_train + n_val]
y_obs = y_obs.unsqueeze(0)  # [1, window, 1]
u_obs = u_obs.unsqueeze(0)  # [1, window, 1]

# Build the true future control sequence
start = n_train + n_val + window
end = start + horizon
u_fut = torch.from_numpy(
    u_raw[start:end]
).float().unsqueeze(0).unsqueeze(-1)  # [1, horizon, 1]

# Forecast with ensemble sampling
y_pred_norm, y_var_norm = model.forecast(
    y_obs,
    a_obs=u_obs,
    horizon=horizon,
    actions_future=u_fut,
    use_map=False,
    num_samples=50
)

y_pred_norm = y_pred_norm.detach().cpu().numpy().flatten()  # [horizon]
y_std_norm = np.sqrt(y_var_norm.detach().cpu().numpy().flatten())

# Convert back to raw scale
y_true_raw = y_raw[start:end]           # [horizon]
y_pred_raw = y_pred_norm * y_sd + y_mu  # [horizon]
y_std_raw = y_std_norm * y_sd           # [horizon]

# Compute error metrics on raw scale
rmse = np.sqrt(np.mean((y_pred_raw - y_true_raw)**2))
mae = np.mean(np.abs(y_pred_raw - y_true_raw))
denom = np.where(y_true_raw==0, 1e-6, y_true_raw)
mape = np.mean(np.abs((y_pred_raw - y_true_raw)/denom))*100

print("\n\n")
print(f"Test RMSE: {rmse:.4f}")
print(f"Test MAE: {mae:.4f}")
print(f"Test MAPE: {mape:.2f}%")

# Plot results
print("\n\n")
t_full = np.arange(len(y_raw))
t_ctx = np.arange(n_train + n_val, n_train + n_val + window)
t_fut = np.arange(start, end)

plt.figure(figsize=(8, 4))
plt.plot(t_full, y_raw * y_sd + y_mu, 'k-', alpha=0.3, label='Data')
plt.plot(t_fut, y_true_raw, 'g--', label='True Test')
plt.plot(t_fut, y_pred_raw, 'r-', label='Forecast')
plt.fill_between(
    t_fut,
    y_pred_raw - 1.96 * y_std_raw,
    y_pred_raw + 1.96 * y_std_raw,
    color='r',
    alpha=0.2
)
plt.axvspan(t_ctx[0], t_ctx[-1], color='gray', alpha=0.1, label='Context')
plt.xlabel('Time Step')
plt.ylabel('Position')
plt.legend()
plt.title('GPSSM Actuator Forecast')
plt.tight_layout()
plt.show()
# Out:
# Epoch 001 | train NELBO = 1514.5904 | val NELBO = 1563.0726
# Epoch 002 | train NELBO = 1351.3010 | val NELBO = 1278.4467
# Epoch 003 | train NELBO = 1158.9298 | val NELBO = 1145.3712
# Epoch 004 | train NELBO = 1107.6072 | val NELBO = 1106.5637
# Epoch 005 | train NELBO = 1093.4826 | val NELBO = 1149.6463
# Epoch 006 | train NELBO = 1036.7191 | val NELBO = 1047.6227
# Epoch 007 | train NELBO = 1022.4013 | val NELBO = 1022.6283
# Epoch 008 | train NELBO = 1002.7624 | val NELBO = 1007.9796
# Epoch 009 | train NELBO = 981.0232 | val NELBO = 997.5987
# Epoch 010 | train NELBO = 977.0851 | val NELBO = 1026.2200
# Epoch 011 | train NELBO = 969.2594 | val NELBO = 985.1353
# Epoch 012 | train NELBO = 962.4122 | val NELBO = 979.6137
# Epoch 013 | train NELBO = 958.3098 | val NELBO = 972.6917
# Epoch 014 | train NELBO = 952.4697 | val NELBO = 956.8145
# Epoch 015 | train NELBO = 944.6691 | val NELBO = 962.4461
# Epoch 016 | train NELBO = 940.3861 | val NELBO = 939.2573
# Epoch 017 | train NELBO = 929.1336 | val NELBO = 967.6926
# Epoch 018 | train NELBO = 920.6008 | val NELBO = 945.8095
# Epoch 019 | train NELBO = 914.1250 | val NELBO = 936.0223
# Epoch 020 | train NELBO = 901.9282 | val NELBO = 905.2148
# Epoch 021 | train NELBO = 895.6722 | val NELBO = 913.5727
# Epoch 022 | train NELBO = 889.7553 | val NELBO = 930.0844
# Epoch 023 | train NELBO = 886.8736 | val NELBO = 895.8157
# Epoch 024 | train NELBO = 880.2608 | val NELBO = 890.4394
# Epoch 025 | train NELBO = 874.8883 | val NELBO = 896.8092
# Epoch 026 | train NELBO = 869.5796 | val NELBO = 877.1897
# Epoch 027 | train NELBO = 865.8433 | val NELBO = 896.2430
# Epoch 028 | train NELBO = 859.9198 | val NELBO = 902.2434
# Epoch 029 | train NELBO = 854.6685 | val NELBO = 870.6277
# Epoch 030 | train NELBO = 864.2996 | val NELBO = 866.9187
# Epoch 031 | train NELBO = 844.5191 | val NELBO = 869.1570
# Epoch 032 | train NELBO = 839.6302 | val NELBO = 846.1617
# Epoch 033 | train NELBO = 922.8760 | val NELBO = 1595.1505
# Epoch 034 | train NELBO = 975.7783 | val NELBO = 843.1105
# Epoch 035 | train NELBO = 1068.8458 | val NELBO = 889.2156
# Epoch 036 | train NELBO = 824.7997 | val NELBO = 1122.4144
# Epoch 037 | train NELBO = 1403.1197 | val NELBO = 2340.4217
# Epoch 038 | train NELBO = 1541.2999 | val NELBO = 2576.4115
# Epoch 039 | train NELBO = 1148.1747 | val NELBO = 821.9383
# Epoch 040 | train NELBO = 1021.2247 | val NELBO = 806.0074
# Epoch 041 | train NELBO = 913.7886 | val NELBO = 912.2101
# Epoch 042 | train NELBO = 839.6075 | val NELBO = 816.6461
# Epoch 043 | train NELBO = 864.0987 | val NELBO = 803.2554
# Epoch 044 | train NELBO = 815.7236 | val NELBO = 785.1686
# Epoch 045 | train NELBO = 1700.9882 | val NELBO = 779.6801
# Epoch 046 | train NELBO = 905.4602 | val NELBO = 1887.6076
# Epoch 047 | train NELBO = 2019.1811 | val NELBO = 3972.2977
# Epoch 048 | train NELBO = 1946.3905 | val NELBO = 1517.9284
# Epoch 049 | train NELBO = 895.0078 | val NELBO = 769.7470
# Epoch 050 | train NELBO = 1288.9896 | val NELBO = 964.0765
# Epoch 051 | train NELBO = 978.1853 | val NELBO = 795.8138
# Epoch 052 | train NELBO = 1276.1059 | val NELBO = 2473.2488
# Epoch 053 | train NELBO = 1543.3917 | val NELBO = 1727.4919
# Epoch 054 | train NELBO = 1910.0403 | val NELBO = 819.0494
# Epoch 055 | train NELBO = 1606.9229 | val NELBO = 841.1897
# Epoch 056 | train NELBO = 1700.1716 | val NELBO = 2675.3536
# Epoch 057 | train NELBO = 1635.0531 | val NELBO = 772.0520
# Epoch 058 | train NELBO = 958.3427 | val NELBO = 2212.8381
# Epoch 059 | train NELBO = 1932.2693 | val NELBO = 889.0857
# Epoch 060 | train NELBO = 914.1046 | val NELBO = 1129.3648
# Epoch 061 | train NELBO = 1148.2311 | val NELBO = 1203.6827
# Epoch 062 | train NELBO = 890.8007 | val NELBO = 1780.9287
# Epoch 063 | train NELBO = 2262.5676 | val NELBO = 739.3184
# Epoch 064 | train NELBO = 1453.6946 | val NELBO = 948.1590
# Epoch 065 | train NELBO = 1988.7511 | val NELBO = 2869.9311
# Epoch 066 | train NELBO = 881.4087 | val NELBO = 809.0649
# Epoch 067 | train NELBO = 686.5186 | val NELBO = 1216.0248
# Epoch 068 | train NELBO = 1201.6449 | val NELBO = 709.3762
# Epoch 069 | train NELBO = 2626.7246 | val NELBO = 1196.1835
# Epoch 070 | train NELBO = 1026.6476 | val NELBO = 1618.3331
# Epoch 071 | train NELBO = 7007.3296 | val NELBO = 1529.9573
# Epoch 072 | train NELBO = 868.0737 | val NELBO = 726.4329
# Epoch 073 | train NELBO = 781.4977 | val NELBO = 1073.6881
# Epoch 074 | train NELBO = 743.9672 | val NELBO = 670.5654
# Epoch 075 | train NELBO = 1367.5853 | val NELBO = 2129.5328
# Epoch 076 | train NELBO = 1396.2415 | val NELBO = 1259.7177
# Epoch 077 | train NELBO = 4387.5810 | val NELBO = 2043.0520
# Epoch 078 | train NELBO = 1238.2954 | val NELBO = 917.8807
# Epoch 079 | train NELBO = 770.8612 | val NELBO = 884.7604
# Epoch 080 | train NELBO = 786.2766 | val NELBO = 688.3297
# Epoch 081 | train NELBO = 740.4460 | val NELBO = 1314.6754
# Epoch 082 | train NELBO = 853.8928 | val NELBO = 651.2705
# Epoch 083 | train NELBO = 872.0376 | val NELBO = 780.2021
# Epoch 084 | train NELBO = 818.4231 | val NELBO = 617.9750
# Epoch 085 | train NELBO = 639.5434 | val NELBO = 726.5959
# Epoch 086 | train NELBO = 1559.0318 | val NELBO = 591.9548
# Epoch 087 | train NELBO = 1096.2806 | val NELBO = 2279.0945
# Epoch 088 | train NELBO = 7933.8261 | val NELBO = 1084.9482
# Epoch 089 | train NELBO = 990.3579 | val NELBO = 1239.2909
# Epoch 090 | train NELBO = 943.2026 | val NELBO = 2325.5360
# Epoch 091 | train NELBO = 1039.7363 | val NELBO = 792.0530
# Epoch 092 | train NELBO = 1669.9571 | val NELBO = 5293.4290
# Epoch 093 | train NELBO = 1393.4208 | val NELBO = 3855.0997
# Epoch 094 | train NELBO = 893.4242 | val NELBO = 1509.4086
# Epoch 095 | train NELBO = 1989.6382 | val NELBO = 1652.8677
# Epoch 096 | train NELBO = 1075.3932 | val NELBO = 603.7933
# Epoch 097 | train NELBO = 2158.6992 | val NELBO = 630.9156
# Epoch 098 | train NELBO = 1172.2965 | val NELBO = 1576.3483
# Epoch 099 | train NELBO = 1107.5261 | val NELBO = 1023.2467
# Epoch 100 | train NELBO = 1447.8569 | val NELBO = 1388.0704
# Epoch 101 | train NELBO = 2367.7530 | val NELBO = 1521.6682
# Epoch 102 | train NELBO = 1205.1082 | val NELBO = 1338.0031
# Epoch 103 | train NELBO = 823.8561 | val NELBO = 1361.8250
# Epoch 104 | train NELBO = 1242.3757 | val NELBO = 517.9849
# Epoch 105 | train NELBO = 1652.2126 | val NELBO = 557.5190
# Epoch 106 | train NELBO = 939.9374 | val NELBO = 791.7513
# Epoch 107 | train NELBO = 769.7253 | val NELBO = 2079.5369
# Epoch 108 | train NELBO = 1504.4826 | val NELBO = 2369.5172
# Epoch 109 | train NELBO = 1376.2870 | val NELBO = 556.2179
# Epoch 110 | train NELBO = 13156.9719 | val NELBO = 75416.2745
# Epoch 111 | train NELBO = 30888.9204 | val NELBO = 6783.9477
# Epoch 112 | train NELBO = 4128.4260 | val NELBO = 12888.7560
# Epoch 113 | train NELBO = 5634.8447 | val NELBO = 2265.8078
# Epoch 114 | train NELBO = 3677.5330 | val NELBO = 1989.2135
# Epoch 115 | train NELBO = 3723.7989 | val NELBO = 6991.9562
# Epoch 116 | train NELBO = 2871.5877 | val NELBO = 2841.5364
# Epoch 117 | train NELBO = 3368.0264 | val NELBO = 2967.3506
# Epoch 118 | train NELBO = 3618.7887 | val NELBO = 4180.0994
# Epoch 119 | train NELBO = 2861.2855 | val NELBO = 2932.3584
# Epoch 120 | train NELBO = 2089.2645 | val NELBO = 2343.9048
# Epoch 121 | train NELBO = 2385.1379 | val NELBO = 1478.3487
# Epoch 122 | train NELBO = 1983.3667 | val NELBO = 1299.8385
# Epoch 123 | train NELBO = 1602.7333 | val NELBO = 2790.4498
# Epoch 124 | train NELBO = 1443.5251 | val NELBO = 2087.5811
# Epoch 125 | train NELBO = 1478.6446 | val NELBO = 1302.7569
# Epoch 126 | train NELBO = 1764.8195 | val NELBO = 1027.0508
# Epoch 127 | train NELBO = 922.4115 | val NELBO = 1112.5276
# Epoch 128 | train NELBO = 1113.2529 | val NELBO = 1069.4144
# Epoch 129 | train NELBO = 890.2418 | val NELBO = 841.3058
# Epoch 130 | train NELBO = 1422.8414 | val NELBO = 694.8632
# Epoch 131 | train NELBO = 745.3679 | val NELBO = 734.8407
# Epoch 132 | train NELBO = 651.8597 | val NELBO = 622.6695
# Epoch 133 | train NELBO = 902.4073 | val NELBO = 649.1903
# Epoch 134 | train NELBO = 946.5847 | val NELBO = 763.8759
# Epoch 135 | train NELBO = 927.5179 | val NELBO = 591.9638
# Epoch 136 | train NELBO = 664.9049 | val NELBO = 623.7316
# Epoch 137 | train NELBO = 2518.7143 | val NELBO = 880.8417
# Epoch 138 | train NELBO = 681.7189 | val NELBO = 514.2484
# Epoch 139 | train NELBO = 783.7467 | val NELBO = 578.9701
# Epoch 140 | train NELBO = 628.2783 | val NELBO = 865.7639
# Epoch 141 | train NELBO = 810.7630 | val NELBO = 1351.7589
# Epoch 142 | train NELBO = 556.5415 | val NELBO = 588.5890
# Epoch 143 | train NELBO = 659.6650 | val NELBO = 841.3966
# Epoch 144 | train NELBO = 626.0413 | val NELBO = 769.5827
# Epoch 145 | train NELBO = 534.9034 | val NELBO = 485.9777
# Epoch 146 | train NELBO = 740.5397 | val NELBO = 459.4844
# Epoch 147 | train NELBO = 1321.4460 | val NELBO = 1955.7627
# Epoch 148 | train NELBO = 806.2569 | val NELBO = 453.2122
# Epoch 149 | train NELBO = 550.5397 | val NELBO = 466.8492
# Epoch 150 | train NELBO = 760.3775 | val NELBO = 906.9278
# Epoch 151 | train NELBO = 652.9163 | val NELBO = 381.5550
# Epoch 152 | train NELBO = 678.4140 | val NELBO = 448.2140
# Epoch 153 | train NELBO = 744.5538 | val NELBO = 1515.8026
# Epoch 154 | train NELBO = 481.3382 | val NELBO = 857.4815
# Epoch 155 | train NELBO = 1710.0654 | val NELBO = 4064.2594
# Epoch 156 | train NELBO = 1220.1109 | val NELBO = 728.9032
# Epoch 157 | train NELBO = 699.4216 | val NELBO = 680.0468
# Epoch 158 | train NELBO = 1453.8195 | val NELBO = 506.1223
# Epoch 159 | train NELBO = 1393.7826 | val NELBO = 5750.0888
# Epoch 160 | train NELBO = 1311.9211 | val NELBO = 494.4074
# Epoch 161 | train NELBO = 359.8156 | val NELBO = 325.1874
# Epoch 162 | train NELBO = 844.5340 | val NELBO = 748.9960
# Epoch 163 | train NELBO = 644.0479 | val NELBO = 2071.8044
# Epoch 164 | train NELBO = 1175.3766 | val NELBO = 334.8171
# Epoch 165 | train NELBO = 1271.3892 | val NELBO = 21677.0385
# Epoch 166 | train NELBO = 1936.8332 | val NELBO = 348.4722
# Epoch 167 | train NELBO = 999.6035 | val NELBO = 1688.6195
# Epoch 168 | train NELBO = 342.5078 | val NELBO = 296.6699
# Epoch 214 | train NELBO = 2080.5384 | val NELBO = 351.9474
# Epoch 215 | train NELBO = 897.6288 | val NELBO = 488.4997
# Epoch 216 | train NELBO = 2790.7928 | val NELBO = 1111.6901
# Epoch 217 | train NELBO = 332.8717 | val NELBO = 634.1190
# Epoch 218 | train NELBO = 230.4297 | val NELBO = 490.0012
# Epoch 219 | train NELBO = 309.1516 | val NELBO = 543.5729
# Epoch 220 | train NELBO = 371.8283 | val NELBO = 285.4308
# Epoch 221 | train NELBO = 269.7072 | val NELBO = 119.0321
# Epoch 222 | train NELBO = 191.2555 | val NELBO = 690.5196
# Epoch 223 | train NELBO = 1420.9917 | val NELBO = 64.0011
# Epoch 224 | train NELBO = 78.2313 | val NELBO = 415.2386
# Epoch 225 | train NELBO = 250.9812 | val NELBO = 120.3571
# Epoch 226 | train NELBO = 445.2040 | val NELBO = 665.4981
# Epoch 227 | train NELBO = 4631.2557 | val NELBO = 781.2403
# Epoch 228 | train NELBO = 986.4456 | val NELBO = 201.3823
# Epoch 229 | train NELBO = 516.4977 | val NELBO = 1918.0837
# Epoch 230 | train NELBO = 6632.0464 | val NELBO = 358.5184
# Epoch 231 | train NELBO = 430.8287 | val NELBO = 757.6576
# Epoch 232 | train NELBO = 374.6657 | val NELBO = 411.6664
# Epoch 233 | train NELBO = 321.3311 | val NELBO = 181.2228
# Epoch 234 | train NELBO = 448.7123 | val NELBO = 195.8051
# Epoch 235 | train NELBO = 389.1003 | val NELBO = 475.3202
# Epoch 236 | train NELBO = 1020.6833 | val NELBO = 2900.2670
# Epoch 237 | train NELBO = 2119.6163 | val NELBO = 470.1554
# Epoch 238 | train NELBO = 341.3013 | val NELBO = 107.7916
# Epoch 239 | train NELBO = 708.8858 | val NELBO = 3677.4809
# Epoch 240 | train NELBO = 3323.8689 | val NELBO = 768.1723
# Epoch 241 | train NELBO = 186.6770 | val NELBO = 302.5471
# Epoch 242 | train NELBO = 103.3321 | val NELBO = -19.4443
# Epoch 243 | train NELBO = -53.9635 | val NELBO = 219.9400
# Epoch 244 | train NELBO = 424.2541 | val NELBO = 562.5452
# Epoch 245 | train NELBO = 167.3435 | val NELBO = 17.4106
# Epoch 246 | train NELBO = 431.1834 | val NELBO = 64.9735
# Epoch 247 | train NELBO = 235.6405 | val NELBO = 843.0341
# Epoch 248 | train NELBO = 531.6602 | val NELBO = 246.1665
# Epoch 249 | train NELBO = 379.2976 | val NELBO = 3.5312
# Epoch 250 | train NELBO = 59.2421 | val NELBO = 4.7441
# Epoch 251 | train NELBO = -39.6167 | val NELBO = 105.0626
# Epoch 252 | train NELBO = 51.9544 | val NELBO = 184.7383
# Epoch 253 | train NELBO = 607.1346 | val NELBO = 1496.1004
# Epoch 254 | train NELBO = 982.9280 | val NELBO = 3483.6709
# Epoch 255 | train NELBO = 1472.6703 | val NELBO = 1781.2894
# Epoch 256 | train NELBO = 2281.7192 | val NELBO = 219.7972
# Epoch 257 | train NELBO = 282.8624 | val NELBO = 1778.9807
# Epoch 258 | train NELBO = 683.1701 | val NELBO = 15.0353
# Epoch 259 | train NELBO = 23.2163 | val NELBO = 364.3806
# Epoch 260 | train NELBO = 392.9582 | val NELBO = 2311.4930
# Epoch 261 | train NELBO = 309.4230 | val NELBO = 48.3036
# Epoch 262 | train NELBO = -74.7127 | val NELBO = 81.3808
# Epoch 263 | train NELBO = 75.9515 | val NELBO = 259.4782
# Epoch 264 | train NELBO = 134.5727 | val NELBO = 590.5117
# Epoch 265 | train NELBO = 126.2401 | val NELBO = 351.1631
# Epoch 266 | train NELBO = 10846.9224 | val NELBO = 680.5815
# Epoch 267 | train NELBO = 112.3694 | val NELBO = -60.9939
# Epoch 268 | train NELBO = -18.4856 | val NELBO = 137.8693
# Epoch 269 | train NELBO = -63.4076 | val NELBO = -112.0206
# Epoch 270 | train NELBO = 20.8731 | val NELBO = -103.1050
# Epoch 271 | train NELBO = 151.7753 | val NELBO = 251.7982
# Epoch 272 | train NELBO = 67.2241 | val NELBO = -131.8346
# Epoch 273 | train NELBO = -21.2232 | val NELBO = -38.1438
# Epoch 274 | train NELBO = -59.0746 | val NELBO = 49.4850
# Epoch 275 | train NELBO = -2.7646 | val NELBO = 653.6768
# Epoch 276 | train NELBO = 183.2845 | val NELBO = 9.1349
# Epoch 277 | train NELBO = 1167.3222 | val NELBO = 16.5765
# Epoch 278 | train NELBO = 115.3653 | val NELBO = 37.3287
# Epoch 279 | train NELBO = 410.3455 | val NELBO = 1626.4916
# Epoch 280 | train NELBO = 1394.3804 | val NELBO = 346.8351
# Epoch 281 | train NELBO = 236.4284 | val NELBO = 309.1847
# Epoch 282 | train NELBO = 535.8469 | val NELBO = 157.5907
# Epoch 283 | train NELBO = -57.0014 | val NELBO = -151.2700
# Epoch 284 | train NELBO = -155.7343 | val NELBO = -196.5666
# Epoch 285 | train NELBO = 181.2318 | val NELBO = 419.5424
# Epoch 286 | train NELBO = 5012.0025 | val NELBO = 572.7823
# Epoch 287 | train NELBO = 158.6195 | val NELBO = 2.7773
# Epoch 288 | train NELBO = -124.4410 | val NELBO = -177.3065
# Epoch 289 | train NELBO = 105.3744 | val NELBO = -75.9707
# Epoch 290 | train NELBO = -157.7367 | val NELBO = -140.7400
# Epoch 291 | train NELBO = -195.1371 | val NELBO = -76.8983
# Epoch 292 | train NELBO = -198.1199 | val NELBO = 825.9095
# Epoch 293 | train NELBO = 106.0466 | val NELBO = -165.9952
# Epoch 294 | train NELBO = 115.0128 | val NELBO = 364.8318
# Epoch 295 | train NELBO = 862.8619 | val NELBO = 548.5708
# Epoch 296 | train NELBO = 576.9554 | val NELBO = 287.9542
# Epoch 297 | train NELBO = 169.1980 | val NELBO = 261.0280
# Epoch 298 | train NELBO = 8.8712 | val NELBO = -91.0701
# Epoch 299 | train NELBO = 140.9450 | val NELBO = 206.6722
# Epoch 300 | train NELBO = 678.3363 | val NELBO = 408.3662
# Restored parameters from epoch 284 (NELBO=-196.5666)
#
#
#
# Test RMSE: 0.1619
# Test MAE: 0.1390
# Test MAPE: 149.70%
