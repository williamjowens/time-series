# %% [markdown]
# # Imports

# %%
import math
import copy
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from torch import Tensor
import numpy as np
import matplotlib.pyplot as plt
from typing import Tuple, Optional

torch.set_default_dtype(torch.float32)

# %% [markdown]
# # RBF Kernel

# %%
# RBF kernel with learnable hyperparameters and jitter
def rbf_kernel(
        x1: torch.Tensor,
        x2: torch.Tensor,
        lengthscale: float,
        variance: float,
        jitter: float = 1e-6
    ) -> torch.Tensor:
    """
    Radial Basis Function (RBF) kernel with learnable log-hyperparameters and jitter.
    k(x, x') = variance * exp(-0.5 * ||x - x'||^2 / lengthscale^2)
    """
    diff = x1.unsqueeze(1) - x2.unsqueeze(0)  # [N, M, D]
    K = variance * torch.exp(-0.5 * (diff**2).sum(-1) / lengthscale**2)  # [N, M]

    # Add jitter on the diagonal when x1 == x2
    if x1.shape == x2.shape and torch.allclose(x1, x2):
        K = K + jitter * torch.eye(x1.size(0), device=K.device, dtype=K.dtype)

    return K

# %% [markdown]
# # Sparse GP Class

# %%
# Sparse GP Transition Model
class SparseGP(nn.Module):
    """
    Sparse, mean-field variational GP for the transition:
      q(u_d) = N(m_d, S_d),  p(u_d) = N(mean(Z), Kzz)
    Posterior predictive:
      mu_d(x) = mean_d(x) + k(x,Z) Kzz^{-1} (m_d - mean_d(Z))
      var_d(x) = k(x,x) - k(x,Z) Kzz^{-1} [Kzz - S_d] Kzz^{-1} k(Z,x)
    """
    def __init__(self, Z: torch.Tensor, state_dim: int):
        super().__init__()
        self.Z = Z
        self.M, self.input_dim = Z.shape
        self.state_dim = state_dim

        # Learnable GP hyperparameters: log-lengthscale and log-variance
        self.log_ls = nn.Parameter(torch.zeros(()))
        self.log_var = nn.Parameter(torch.zeros(()))

        # Variational parameters; set in init_variational
        self.m = None  # [D, M]
        self.S = None  # [D, M, M]

    def init_variational(self, D: int):
        """Initialize q(u_d)=N(m_d, S_d) with S_d = Kzz."""
        self.m = nn.Parameter(torch.zeros(D, self.M))
        with torch.no_grad():
            Kzz = rbf_kernel(
                self.Z,
                self.Z,
                self.log_ls.exp(),
                self.log_var.exp()
            )
        S0 = Kzz.unsqueeze(0).repeat(D, 1, 1)
        self.S = nn.Parameter(S0)

    def prior_Kzz(self) -> torch.Tensor:
        """Compute the prior covariance Kzz = k(Z, Z)."""
        return rbf_kernel(
            self.Z,
            self.Z,
            self.log_ls.exp(),
            self.log_var.exp()
        )

    def kl_U(self) -> torch.Tensor:
        """
        KL[q(U) || p(U)] summed over output dimensions.
        p(u_d)=N(mean(Z), Kzz), mean_d(Z)=Z[:, d].
        """
        Kzz = self.prior_Kzz()   # [M, M]
        Ki = torch.inverse(Kzz)  # [M, M]
        logdet_K = torch.logdet(Kzz)
        D = self.m.size(0)

        # Mean(Z): [D, M], each row d = Z[:, d]
        meanZ = self.Z[:, :self.state_dim].t()  # [D, M]

        kl = 0.0
        for d in range(D):
            md, Sd = self.m[d], self.S[d]  # md:[M], Sd:[M,M]
            trace_term = torch.trace(Ki @ Sd)
            quad_term = (md - meanZ[d]) @ (Ki @ (md - meanZ[d]))
            logdet_S = torch.logdet(Sd)
            kl += 0.5 * (trace_term + quad_term - self.M + logdet_K - logdet_S)
        return kl

    def predict_f(
            self,
            x: torch.Tensor
        ) -> Tuple[torch.Tensor, torch.Tensor]:
        """
        Posterior predictive mean and variance at inputs x.
        Args:
          x: [B, input_dim]
        Returns:
          mu:  [B, D]
          var: [B, D]
        """
        B = x.size(0)
        D = self.m.size(0)
        sigma_f2 = self.log_var.exp()
        ls = self.log_ls.exp()

        Kzz = self.prior_Kzz()
        Ki = torch.inverse(Kzz)
        Kxz = rbf_kernel(x, self.Z, ls, sigma_f2)  # [B, M]

        meanX = x[:, :self.state_dim]              # [B, D]
        meanZ = self.Z[:, :self.state_dim].t()     # [D, M]

        mu = torch.zeros(B, D, dtype=x.dtype, device=x.device)
        var = torch.zeros(B, D, dtype=x.dtype, device=x.device)

        for d in range(D):
            md, Sd = self.m[d], self.S[d]
            mu[:, d] = meanX[:, d] + Kxz @ (Ki @ (md - meanZ[d]))
            kxx = sigma_f2 * torch.ones(B, dtype=x.dtype, device=x.device)
            tmp = Ki @ (Kzz - Sd) @ Ki
            var[:, d] = kxx - torch.sum((Kxz @ tmp) * Kxz, dim=1)

        # Clamp for stability
        var = var.clamp(min=1e-6)
        return mu, var

# %% [markdown]
# # Recognition Network

# %%
# Recognition Network for q(X)
class RecognitionNet(nn.Module):
    """
    Bidirectional GRU -> parameters of q(x0), q(xt | x_{t-1}):
      q(x0)=N(m0, L0 L0^T),  q(xt|x_{t-1})=N(A_t x_{t-1}, L_t L_t^T)
    """
    def __init__(
            self,
            obs_dim: int,
            act_dim: int,
            hid_dim: int,
            state_dim: int
        ):
        super().__init__()
        self.state_dim = state_dim
        self.rnn = nn.GRU(
            obs_dim + act_dim,
            hid_dim,
            batch_first=True,
            bidirectional=True
        )
        D = state_dim
        self.lin_A = nn.Linear(2 * hid_dim, D * D)
        self.lin_L = nn.Linear(2 * hid_dim, D * (D + 1) // 2)
        self.lin_m0 = nn.Linear(hid_dim, D)
        self.lin_L0 = nn.Linear(hid_dim, D * (D + 1) // 2)

    def forward(self, y: torch.Tensor, a: torch.Tensor):
        """
        Encode observations+actions -> {m0, L0}, {A_t, L_t}.

        Args:
          y: [B, T, obs_dim]
          a: [B, T, act_dim]
        Returns:
          m0:   [B, D]
          L0_f: [B, D*(D+1)//2]
          A:    [B, T, D, D]
          L_f:  [B, T, D*(D+1)//2]
        """
        B, T, _ = y.shape
        inp = torch.cat([y, a], dim=-1)       # [B, T, obs+act]
        H, h_n = self.rnn(inp)                # H:[B,T,2H], h_n:[2,B,H]

        D = self.state_dim
        A_flat = self.lin_A(H).view(B, T, D, D)
        L_flat = self.lin_L(H)                # [B, T, D*(D+1)//2]

        # Backward final hidden -> x0 params
        h_back = h_n[1]                       # [B, H]
        m0 = self.lin_m0(h_back)              # [B, D]
        L0_f = self.lin_L0(h_back)            # [B, D*(D+1)//2]

        return m0, L0_f, A_flat, L_flat

# %%
def flat_to_lower(Lf: torch.Tensor, D: int) -> torch.Tensor:
    """
    Out-of-place conversion of flat triangular entries to a lower-triangular matrix L.
    Lf: [N, M] where M = D*(D+1)//2
    Returns L: [N, D, D], with diag entries softplus’d.
    """
    # Lf is shape [N, M]
    N, M = Lf.shape
    device, dtype = Lf.device, Lf.dtype

    # Tril indices once
    idx0, idx1 = torch.tril_indices(D, D, device=device)
    # Compute linear indices into a (D*D) vector
    lin_idx = idx0 * D + idx1  # [M]
    lin_idx = lin_idx.unsqueeze(0).expand(N, -1)  # [N, M]

    # Start with a flat [N, D*D] zero tensor
    out_flat = torch.zeros(N, D*D, device=device, dtype=dtype)
    # Scatter Lf into the lower-triangular positions
    out_flat = out_flat.scatter(1, lin_idx, Lf)

    # Apply softplus to the diagonal entries
    # Diagonal linear indices are 0, D+1, 2(D+1), ..., (D-1)(D+1)
    diag_idx = torch.arange(0, D*D, D+1, device=device)
    diag_idx = diag_idx.unsqueeze(0).expand(N, -1)  # [N, D]
    # Gather current diag
    diag_vals = out_flat.gather(1, diag_idx)        # [N, D]
    # Softplus
    diag_sp = torch.nn.functional.softplus(diag_vals)
    # Scatter them back
    out_flat = out_flat.scatter(1, diag_idx, diag_sp)

    # Reshape into [N, D, D]
    return out_flat.view(N, D, D)

# %% [markdown]
# # GPSSM Class

# %%
# GPSSM Model and Exact ELBO
class GPSSM(nn.Module):
    """
    Full GPSSM model:
      - SparseGP transition
      - RecognitionNet posterior
      - Exact ELBO: KL[u], KL[x0], H[q(X)], E[log p(y|x)], E[log p(x|f)]
    """
    def __init__(
            self,
            obs_dim: int,
            act_dim: int,
            state_dim: int,
            hid_dim: int,
            Z: torch.Tensor,
            num_mc_samples: int = 1
        ):
        super().__init__()
        self.state_dim = state_dim
        self.num_mc = num_mc_samples

        # (1) Sparse GP transition
        self.gp = SparseGP(Z, state_dim)
        self.gp.init_variational(state_dim)

        # (2) Recognition network q(X)
        self.rec = RecognitionNet(obs_dim, act_dim, hid_dim, state_dim)

        # (3) Observation model p(y_t|x_t)=N(Wg x_t + bg, sigma_g2 I)
        self.Wg = nn.Linear(state_dim, obs_dim, bias=True)
        self.log_sigma_g2 = nn.Parameter(torch.zeros(()))

    def elbo(self, y: torch.Tensor, a: torch.Tensor) -> torch.Tensor:
        """
        Compute one-sample ELBO estimate:
            ELBO = Eq_x0 + H[q(X)] - KL[q(U)||p(U)]
                 + E_q[log p(y|x)] + E_q[log p(x|f)]
        Returns:
            ELBO averaged over batch
        """
        B, T, _ = y.shape
        D = self.state_dim

        # Unpack q(X)
        m0, L0_f, A, L_f = self.rec(y, a)
        L0 = flat_to_lower(L0_f, D)                    # [B, D, D]
        Lt = flat_to_lower(L_f.reshape(B * T, -1), D)  # [B*T, D, D]
        Lt = Lt.reshape(B, T, D, D).contiguous()       # Break any strides

        # KL over GP inducing points (U)
        kl_u = self.gp.kl_U()

        # KL over initial state q(x0)||p(x0)=N(0,I)
        Sigma0 = L0 @ L0.transpose(-1, -2)               # [B, D, D]
        tr0 = Sigma0.diagonal(dim1=-2, dim2=-1).sum(-1)  # [B]
        ld0 = torch.logdet(Sigma0 + 1e-6*torch.eye(D, device=Sigma0.device))  # [B]
        m0norm2 = (m0**2).sum(-1)                        # [B]
        kl_x0 = 0.5 * torch.sum(tr0 + m0norm2 - D - ld0)

        # Entropy H[q(X)]
        H_const = 0.5 * (T + 1) * D * math.log(2*math.pi*math.e)
        # Vectorised log-dets of LtLt^T
        Lt_flat = Lt.reshape(B*T, D, D)
        SigmaL = Lt_flat @ Lt_flat.transpose(-1, -2)   # [B*T, D, D]
        ld_Lt = torch.logdet(SigmaL)                   # [B*T]
        ld_Lt_bt = ld_Lt.reshape(B, T)                 # [B, T]
        # Assemble entropy
        H_term = H_const + 0.5 * torch.sum(ld0.unsqueeze(-1) + ld_Lt_bt)

        # Observation term E_q[log p(y|x)]
        sigma_g2 = torch.exp(self.log_sigma_g2)
        m_t, S_t = m0, Sigma0
        Ey_terms = []
        for t in range(T):
            mu_y = self.Wg(m_t)
            cov  = (
                self.Wg.weight @ S_t @ self.Wg.weight.t()
                + sigma_g2 * torch.eye(
                    mu_y.size(-1),
                    dtype=mu_y.dtype,
                    device=mu_y.device
                )
            )
            diff = (y[:,t] - mu_y).unsqueeze(-1)  # [B,1,1]
            Ey = -0.5 * torch.sum(
                diff.transpose(-1,-2) @ torch.inverse(cov) @ diff
                + torch.logdet(2*torch.pi*cov),
                dim=(1, 2)
            )  # [B]
            Ey_terms.append(Ey)
            # Propagate forward
            m_t = (A[:,t] @ m_t.unsqueeze(-1)).squeeze(-1)
            S_t = (A[:,t] @ S_t @ A[:,t].transpose(-1,-2)
                + Lt[:,t] @ Lt[:,t].transpose(-1,-2))
        E_logy = torch.sum(torch.stack(Ey_terms))  # scalar

        # Transition term (MC)
        trans_samples = []
        for _ in range(self.num_mc):
            eps0 = torch.randn(B, D, 1, dtype=y.dtype, device=y.device)
            x_prev = m0.unsqueeze(-1) + L0 @ eps0
            lp_list = []
            for t in range(T):
                inp = torch.cat([x_prev.squeeze(-1), a[:,t]], dim=-1)
                mu_f, var_f = self.gp.predict_f(inp)  # [B,D]
                mu_f, var_f = mu_f.unsqueeze(-1), var_f.unsqueeze(-1)
                eps = torch.randn_like(var_f)
                x_lin = A[:,t] @ x_prev
                x_t = x_lin + Lt[:,t] @ eps
                diff2 = (x_t - mu_f)**2
                lp = 0.5 * torch.sum(
                    -diff2/var_f
                    - torch.log(2*torch.pi*var_f),
                    dim=(1, 2)
                )  # [B]
                lp_list.append(lp)
                x_prev = x_t
            trans_samples.append(torch.sum(torch.stack(lp_list)))
        trans = torch.mean(torch.stack(trans_samples))  # scalar

        # Combine all terms
        elbo = -kl_u - kl_x0 + H_term + E_logy + trans
        return elbo / B

    def forward(self, y: torch.Tensor, a: torch.Tensor) -> torch.Tensor:
        """Negative ELBO (for minimisation)."""
        return -self.elbo(y, a)

    def forecast(
            self,
            y_obs: torch.Tensor,
            a_obs: torch.Tensor = None,
            horizon: int = 30,
            actions_future: torch.Tensor = None,
            use_map: bool = True,
            num_samples: int = 1
        ):
        """
        Forecast future y for `horizon` steps given observed window (y_obs, a_obs).
        If num_samples>1 and use_map=False, draws multiple sample trajectories
        and averages their means and variances.

        Returns:
            y_means: [horizon, obs_dim]
            y_vars: [horizon, obs_dim]
        """
        B, T, _ = y_obs.shape

        # Default zeros if no actions
        if a_obs is None:
            a_obs = torch.zeros(
                B, T,
                self.gp.input_dim - self.state_dim,
                dtype=y_obs.dtype,
                device=y_obs.device
            )
        if actions_future is None:
            actions_future = torch.zeros(
                B, horizon,
                self.gp.input_dim - self.state_dim,
                dtype=y_obs.dtype,
                device=y_obs.device
            )

        # Infer q(x_T)
        m0, L0_f, A, L_f = self.rec(y_obs, a_obs)
        L0 = flat_to_lower(L0_f, self.state_dim)
        Lt = flat_to_lower(
            L_f.view(B * T, -1),
            self.state_dim
        ).view(
            B, T,
            self.state_dim,
            self.state_dim
        )

        # Propagate to get posterior at t = T
        m_t = m0
        Sigma_t = L0 @ L0.transpose(-1, -2)
        for t in range(T):
            m_t = (A[:, t] @ m_t.unsqueeze(-1)).squeeze(-1)
            Sigma_t = (
                A[:, t] @ Sigma_t @ A[:, t].transpose(-1, -2)
                + Lt[:, t] @ Lt[:, t].transpose(-1, -2)
            )

        # Draw num_samples rollouts
        means_list = []
        vars_list = []
        for _ in range(num_samples):
            x_mean, x_cov = m_t, Sigma_t
            y_means = []
            y_vars = []
            for h in range(horizon):
                u = actions_future[:, h, :]
                inp = torch.cat([x_mean, u], dim=-1)
                mu_f, var_f = self.gp.predict_f(inp)
                if use_map:
                    x_mean, x_cov = mu_f, torch.diag_embed(var_f)
                else:
                    eps = torch.randn_like(mu_f)
                    x_mean = mu_f + torch.sqrt(var_f) * eps
                    x_cov = torch.diag_embed(var_f)

                y_mean = self.Wg(x_mean)
                y_cov = (
                    self.Wg.weight @ x_cov @ self.Wg.weight.t()
                    + torch.exp(self.log_sigma_g2) *
                    torch.eye(
                        y_mean.size(-1),
                        device=y_mean.device
                    )
                )
                y_means.append(y_mean.squeeze(0))
                y_vars.append(
                    torch.diagonal(
                        y_cov,
                        dim1=-2,
                        dim2=-1
                    ).squeeze(0)
                )
            means_list.append(torch.stack(y_means))  # [horizon, obs_dim]
            vars_list.append(torch.stack(y_vars))

        # Aggregate across samples
        means_all = torch.stack(means_list)  # [num_samples, horizon, obs_dim]
        vars_all = torch.stack(vars_list)
        y_means = means_all.mean(0)
        y_vars = vars_all.mean(0)

        return y_means, y_vars

# %% [markdown]
# # Training Utility

# %%
# Training utility
def train(
        model: GPSSM,
        train_loader: DataLoader,
        val_loader: Optional[DataLoader] = None,
        lr: float = 1e-3,
        epochs: int = 100
    ):
    """
    Train GPSSM by minimizing NELBO, snapshotting the parameters
    from the epoch with lowest validation NELBO (if val_loader provided),
    otherwise lowest training NELBO.
    """
    opt = optim.Adam(model.parameters(), lr=lr)
    best_loss = float('inf')
    best_params = None
    best_epoch = -1

    for ep in range(1, epochs+1):
        # Training step
        model.train()
        train_sum = 0.0
        for yb, ab in train_loader:
            loss = model(yb, ab)
            opt.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 5.0)
            opt.step()
            train_sum += loss.item() * yb.size(0)
        train_nelbo = train_sum / len(train_loader.dataset)

        # Evaluation step
        eval_loader = val_loader if val_loader is not None else train_loader
        model.eval()
        eval_sum = 0.0
        with torch.no_grad():
            for yb, ab in eval_loader:
                eval_sum += model(yb, ab).item() * yb.size(0)
        eval_nelbo = eval_sum / len(eval_loader.dataset)

        msg = f"Epoch {ep:03d} | train NELBO = {train_nelbo:.4f}"
        if val_loader is not None:
            msg += f" | val NELBO = {eval_nelbo:.4f}"
        print(msg)

        # Snapshot best
        current = eval_nelbo if val_loader is not None else train_nelbo
        if current < best_loss:
            best_loss = current
            best_epoch = ep
            best_params = copy.deepcopy(model.state_dict())

    # Restore best
    model.load_state_dict(best_params)
    print(f"Restored parameters from epoch {best_epoch} (NELBO={best_loss:.4f})")
    return model

# %% [markdown]
# # Time Series Demo

# %%
# Generate a noisy sine wave
T_total = 300
t = np.arange(T_total)
series = np.sin(0.05 * t) + 0.1 * np.random.randn(T_total)

# Parameters
window = 50
horizon = 30

# %%
# Split into train / val windows

# train: first 200 points (0–200)
train_series = series[:4*window]

# val: next 50 points (200–250)
val_series = series[4*window : 5*window]

# test true: the 30 points after val (250–280)
test_true = series[5*window : 5*window + horizon]

# %%
# Convert to tensors
train_y = torch.from_numpy(train_series) \
               .unsqueeze(0).unsqueeze(-1) \
               .float()  # [1, 200, 1]
train_a = torch.zeros(1, train_y.shape[1], 0).float()

val_y = torch.from_numpy(val_series) \
               .unsqueeze(0).unsqueeze(-1) \
               .float()  # [1,  50, 1]
val_a = torch.zeros(1, val_y.shape[1], 0).float()

# %%
# DataLoaders
train_loader = DataLoader(
    TensorDataset(train_y, train_a),
    batch_size=1,
    shuffle=False
)

val_loader = DataLoader(
    TensorDataset(val_y, val_a),
    batch_size=1,
    shuffle=False
)

# %%
# Instantiate GPSSM
obs_dim, act_dim, state_dim = 1, 0, 4
hid_dim = 20
M = 20
Z = torch.randn(M, state_dim).float()

model = GPSSM(
    obs_dim=obs_dim,
    act_dim=act_dim,
    state_dim=state_dim,
    hid_dim=hid_dim,
    Z=Z,
    num_mc_samples=3
)

# %%
# Train with validation
model = train(
    model,
    train_loader,
    val_loader,
    lr=1e-3,
    epochs=200,
)
# Out:
# Epoch 001 | train NELBO = 789.0997 | val NELBO = 218.5237
# Epoch 002 | train NELBO = 767.0190 | val NELBO = 212.1678
# Epoch 003 | train NELBO = 744.9129 | val NELBO = 214.5984
# Epoch 004 | train NELBO = 727.6471 | val NELBO = 204.2351
# Epoch 005 | train NELBO = 717.6361 | val NELBO = 210.6638
# Epoch 006 | train NELBO = 718.9711 | val NELBO = 211.0731
# Epoch 007 | train NELBO = 715.5548 | val NELBO = 206.6904
# Epoch 008 | train NELBO = 715.8185 | val NELBO = 198.7447
# Epoch 009 | train NELBO = 685.6768 | val NELBO = 207.7246
# Epoch 010 | train NELBO = 684.3994 | val NELBO = 204.0114
# Epoch 011 | train NELBO = 698.7642 | val NELBO = 181.0236
# Epoch 012 | train NELBO = 683.0447 | val NELBO = 185.4200
# Epoch 013 | train NELBO = 679.0529 | val NELBO = 186.5861
# Epoch 014 | train NELBO = 665.4457 | val NELBO = 196.3288
# Epoch 015 | train NELBO = 647.8069 | val NELBO = 181.1262
# Epoch 016 | train NELBO = 651.0760 | val NELBO = 179.5568
# Epoch 017 | train NELBO = 630.0457 | val NELBO = 190.7063
# Epoch 018 | train NELBO = 644.9245 | val NELBO = 188.1082
# Epoch 019 | train NELBO = 640.8113 | val NELBO = 189.3058
# Epoch 020 | train NELBO = 617.9360 | val NELBO = 175.4313
# Epoch 021 | train NELBO = 610.9102 | val NELBO = 186.7871
# Epoch 022 | train NELBO = 640.8861 | val NELBO = 175.7874
# Epoch 023 | train NELBO = 612.0557 | val NELBO = 172.8119
# Epoch 024 | train NELBO = 613.3966 | val NELBO = 176.7747
# Epoch 025 | train NELBO = 605.9553 | val NELBO = 171.8379
# Epoch 026 | train NELBO = 613.3010 | val NELBO = 175.2734
# Epoch 027 | train NELBO = 584.3895 | val NELBO = 169.5649
# Epoch 028 | train NELBO = 587.2749 | val NELBO = 161.4814
# Epoch 029 | train NELBO = 573.5327 | val NELBO = 168.8869
# Epoch 030 | train NELBO = 574.7207 | val NELBO = 164.7694
# Epoch 031 | train NELBO = 576.7150 | val NELBO = 160.9062
# Epoch 032 | train NELBO = 566.1595 | val NELBO = 161.2037
# Epoch 033 | train NELBO = 551.4102 | val NELBO = 159.4656
# Epoch 034 | train NELBO = 541.4730 | val NELBO = 149.4197
# Epoch 035 | train NELBO = 496.8185 | val NELBO = 160.9611
# Epoch 036 | train NELBO = 539.0992 | val NELBO = 146.3717
# Epoch 037 | train NELBO = 511.4237 | val NELBO = 150.2024
# Epoch 038 | train NELBO = 520.6202 | val NELBO = 146.8776
# Epoch 039 | train NELBO = 504.0313 | val NELBO = 148.9606
# Epoch 040 | train NELBO = 476.2921 | val NELBO = 147.7512
# Epoch 041 | train NELBO = 464.7618 | val NELBO = 143.7986
# Epoch 042 | train NELBO = 462.5380 | val NELBO = 141.9845
# Epoch 043 | train NELBO = 458.6685 | val NELBO = 139.8822
# Epoch 044 | train NELBO = 452.4648 | val NELBO = 137.8804
# Epoch 045 | train NELBO = 457.8684 | val NELBO = 135.6391
# Epoch 046 | train NELBO = 419.2919 | val NELBO = 136.6941
# Epoch 047 | train NELBO = 424.8719 | val NELBO = 127.8132
# Epoch 048 | train NELBO = 406.3260 | val NELBO = 132.3094
# Epoch 049 | train NELBO = 388.3669 | val NELBO = 115.7918
# Epoch 050 | train NELBO = 391.3088 | val NELBO = 112.5184
# Epoch 051 | train NELBO = 373.9586 | val NELBO = 111.0375
# Epoch 052 | train NELBO = 381.6330 | val NELBO = 124.7442
# Epoch 053 | train NELBO = 352.3313 | val NELBO = 99.4516
# Epoch 054 | train NELBO = 313.4955 | val NELBO = 103.8824
# Epoch 055 | train NELBO = 324.5584 | val NELBO = 110.4675
# Epoch 056 | train NELBO = 307.1818 | val NELBO = 85.6314
# Epoch 057 | train NELBO = 291.7434 | val NELBO = 90.7374
# Epoch 058 | train NELBO = 286.7925 | val NELBO = 103.2331
# Epoch 059 | train NELBO = 228.8536 | val NELBO = 102.0975
# Epoch 060 | train NELBO = 215.8908 | val NELBO = 65.4499
# Epoch 061 | train NELBO = 197.7061 | val NELBO = 72.7538
# Epoch 062 | train NELBO = 178.5793 | val NELBO = 65.8964
# Epoch 063 | train NELBO = 176.8252 | val NELBO = 74.0062
# Epoch 064 | train NELBO = 130.7756 | val NELBO = 55.8645
# Epoch 065 | train NELBO = 104.6154 | val NELBO = 50.0468
# Epoch 066 | train NELBO = 41.3794 | val NELBO = 49.9728
# Epoch 067 | train NELBO = 58.6219 | val NELBO = 35.3235
# Epoch 068 | train NELBO = 56.0540 | val NELBO = 28.7087
# Epoch 069 | train NELBO = 3.2096 | val NELBO = 18.7453
# Epoch 070 | train NELBO = -25.5374 | val NELBO = 20.8042
# Epoch 071 | train NELBO = -39.6187 | val NELBO = 34.5416
# Epoch 072 | train NELBO = -74.2623 | val NELBO = 3.7364
# Epoch 073 | train NELBO = -60.8521 | val NELBO = 4.3871
# Epoch 074 | train NELBO = -97.8473 | val NELBO = 5.7983
# Epoch 075 | train NELBO = -109.9440 | val NELBO = -5.2902
# Epoch 076 | train NELBO = -107.1515 | val NELBO = -7.1429
# Epoch 077 | train NELBO = -116.8287 | val NELBO = -1.3959
# Epoch 078 | train NELBO = -164.5012 | val NELBO = -8.4966
# Epoch 079 | train NELBO = -160.5513 | val NELBO = -15.0510
# Epoch 080 | train NELBO = -194.8058 | val NELBO = -19.3596
# Epoch 081 | train NELBO = -199.1838 | val NELBO = -21.7615
# Epoch 082 | train NELBO = -216.0944 | val NELBO = -24.9550
# Epoch 083 | train NELBO = -238.2773 | val NELBO = -37.7039
# Epoch 084 | train NELBO = -221.3868 | val NELBO = -34.7767
# Epoch 085 | train NELBO = -260.9996 | val NELBO = -40.6170
# Epoch 086 | train NELBO = -273.3390 | val NELBO = -39.8195
# Epoch 087 | train NELBO = -294.0994 | val NELBO = -47.2989
# Epoch 088 | train NELBO = -292.7770 | val NELBO = -44.3596
# Epoch 089 | train NELBO = -300.3064 | val NELBO = -39.4993
# Epoch 090 | train NELBO = -337.7471 | val NELBO = -46.9733
# Epoch 091 | train NELBO = -345.6414 | val NELBO = -54.9794
# Epoch 092 | train NELBO = -338.2162 | val NELBO = -69.6855
# Epoch 093 | train NELBO = -362.9669 | val NELBO = -52.0790
# Epoch 094 | train NELBO = -358.1411 | val NELBO = -56.8846
# Epoch 095 | train NELBO = -355.3163 | val NELBO = -70.2372
# Epoch 096 | train NELBO = -380.5353 | val NELBO = -51.5948
# Epoch 097 | train NELBO = -387.3987 | val NELBO = -52.6393
# Epoch 098 | train NELBO = -387.0332 | val NELBO = -61.7849
# Epoch 099 | train NELBO = -421.2180 | val NELBO = -75.8333
# Epoch 100 | train NELBO = -421.7189 | val NELBO = -72.2866
# Epoch 101 | train NELBO = -430.4521 | val NELBO = -76.9132
# Epoch 102 | train NELBO = -437.6202 | val NELBO = -77.4240
# Epoch 103 | train NELBO = -455.9445 | val NELBO = -74.2818
# Epoch 104 | train NELBO = -472.4229 | val NELBO = -68.1189
# Epoch 105 | train NELBO = -472.9830 | val NELBO = -93.6148
# Epoch 106 | train NELBO = -465.2340 | val NELBO = -82.4783
# Epoch 107 | train NELBO = -469.5496 | val NELBO = -92.9667
# Epoch 108 | train NELBO = -485.6082 | val NELBO = -81.9673
# Epoch 109 | train NELBO = -495.9043 | val NELBO = -87.6023
# Epoch 110 | train NELBO = -496.4825 | val NELBO = -76.5155
# Epoch 111 | train NELBO = -521.4316 | val NELBO = -84.9488
# Epoch 112 | train NELBO = -516.8556 | val NELBO = -93.0555
# Epoch 113 | train NELBO = -523.0211 | val NELBO = -102.1227
# Epoch 114 | train NELBO = -515.6692 | val NELBO = -89.0944
# Epoch 115 | train NELBO = -543.3483 | val NELBO = -92.9911
# Epoch 116 | train NELBO = -544.8445 | val NELBO = -102.8614
# Epoch 117 | train NELBO = -563.0735 | val NELBO = -102.0579
# Epoch 118 | train NELBO = -545.0488 | val NELBO = -97.4772
# Epoch 119 | train NELBO = -566.2286 | val NELBO = -101.3106
# Epoch 120 | train NELBO = -573.6093 | val NELBO = -100.0395
# Epoch 121 | train NELBO = -603.8702 | val NELBO = -103.6260
# Epoch 122 | train NELBO = -617.7773 | val NELBO = -110.3242
# Epoch 123 | train NELBO = -592.5874 | val NELBO = -115.3474
# Epoch 124 | train NELBO = -594.5701 | val NELBO = -118.1894
# Epoch 125 | train NELBO = -596.0217 | val NELBO = -105.0244
# Epoch 126 | train NELBO = -583.1385 | val NELBO = -121.4194
# Epoch 127 | train NELBO = -626.8846 | val NELBO = -115.1579
# Epoch 128 | train NELBO = -654.0952 | val NELBO = -113.9852
# Epoch 129 | train NELBO = -632.3295 | val NELBO = -111.0753
# Epoch 130 | train NELBO = -657.4930 | val NELBO = -116.5954
# Epoch 131 | train NELBO = -644.1006 | val NELBO = -105.9630
# Epoch 132 | train NELBO = -664.5132 | val NELBO = -129.7074
# Epoch 133 | train NELBO = -632.0233 | val NELBO = -136.9857
# Epoch 134 | train NELBO = -664.4188 | val NELBO = -131.0650
# Epoch 135 | train NELBO = -645.3717 | val NELBO = -131.5366
# Epoch 136 | train NELBO = -684.1589 | val NELBO = -137.6628
# Epoch 137 | train NELBO = -670.5212 | val NELBO = -116.8227
# Epoch 138 | train NELBO = -693.7777 | val NELBO = -129.9856
# Epoch 139 | train NELBO = -696.9113 | val NELBO = -134.1073
# Epoch 140 | train NELBO = -692.5038 | val NELBO = -138.6005
# Epoch 141 | train NELBO = -713.1199 | val NELBO = -143.4158
# Epoch 142 | train NELBO = -716.3107 | val NELBO = -141.8317
# Epoch 143 | train NELBO = -716.9789 | val NELBO = -137.9047
# Epoch 144 | train NELBO = -721.9629 | val NELBO = -137.0977
# Epoch 145 | train NELBO = -733.3289 | val NELBO = -142.0659
# Epoch 146 | train NELBO = -755.3472 | val NELBO = -145.0815
# Epoch 147 | train NELBO = -747.7158 | val NELBO = -135.6399
# Epoch 148 | train NELBO = -746.3519 | val NELBO = -142.1214
# Epoch 149 | train NELBO = -748.9393 | val NELBO = -145.3725
# Epoch 150 | train NELBO = -730.0042 | val NELBO = -134.2788
# Epoch 151 | train NELBO = -778.5846 | val NELBO = -155.0159
# Epoch 152 | train NELBO = -772.7080 | val NELBO = -158.9176
# Epoch 153 | train NELBO = -768.8563 | val NELBO = -152.0717
# Epoch 154 | train NELBO = -815.9381 | val NELBO = -159.1303
# Epoch 155 | train NELBO = -795.2234 | val NELBO = -148.1915
# Epoch 156 | train NELBO = -796.3367 | val NELBO = -151.1597
# Epoch 157 | train NELBO = -762.6501 | val NELBO = -160.2748
# Epoch 158 | train NELBO = -799.1862 | val NELBO = -160.6279
# Epoch 159 | train NELBO = -805.0646 | val NELBO = -150.6207
# Epoch 160 | train NELBO = -776.9360 | val NELBO = -150.7977
# Epoch 161 | train NELBO = -801.5834 | val NELBO = -159.1876
# Epoch 162 | train NELBO = -806.3893 | val NELBO = -154.0378
# Epoch 163 | train NELBO = -829.2220 | val NELBO = -159.5611
# Epoch 164 | train NELBO = -820.4178 | val NELBO = -157.5871
# Epoch 165 | train NELBO = -838.0361 | val NELBO = -151.8124
# Epoch 166 | train NELBO = -852.5299 | val NELBO = -167.7469
# Epoch 167 | train NELBO = -848.0098 | val NELBO = -184.8130
# Epoch 168 | train NELBO = -834.4196 | val NELBO = -177.0784
# Epoch 169 | train NELBO = -848.8708 | val NELBO = -174.0443
# Epoch 170 | train NELBO = -843.3167 | val NELBO = -173.7711
# Epoch 171 | train NELBO = -853.1051 | val NELBO = -180.8513
# Epoch 172 | train NELBO = -853.0568 | val NELBO = -163.9041
# Epoch 173 | train NELBO = -858.4866 | val NELBO = -185.6203
# Epoch 174 | train NELBO = -853.1608 | val NELBO = -167.5171
# Epoch 175 | train NELBO = -851.3516 | val NELBO = -182.0254
# Epoch 176 | train NELBO = -875.1094 | val NELBO = -172.1500
# Epoch 177 | train NELBO = -891.0638 | val NELBO = -159.9749
# Epoch 178 | train NELBO = -868.2405 | val NELBO = -168.6237
# Epoch 179 | train NELBO = -877.2993 | val NELBO = -183.5763
# Epoch 180 | train NELBO = -896.2133 | val NELBO = -169.1123
# Epoch 181 | train NELBO = -907.1880 | val NELBO = -177.8290
# Epoch 182 | train NELBO = -897.2870 | val NELBO = -164.0313
# Epoch 183 | train NELBO = -931.0447 | val NELBO = -182.4770
# Epoch 184 | train NELBO = -909.4246 | val NELBO = -200.2888
# Epoch 185 | train NELBO = -924.0375 | val NELBO = -189.1315
# Epoch 186 | train NELBO = -929.3080 | val NELBO = -183.6094
# Epoch 187 | train NELBO = -929.0980 | val NELBO = -181.1667
# Epoch 188 | train NELBO = -937.7004 | val NELBO = -176.8014
# Epoch 189 | train NELBO = -906.1750 | val NELBO = -205.1491
# Epoch 190 | train NELBO = -942.1582 | val NELBO = -191.0046
# Epoch 191 | train NELBO = -940.0262 | val NELBO = -171.3906
# Epoch 192 | train NELBO = -955.7711 | val NELBO = -165.1476
# Epoch 193 | train NELBO = -926.6808 | val NELBO = -188.4263
# Epoch 194 | train NELBO = -954.0114 | val NELBO = -185.0490
# Epoch 195 | train NELBO = -934.2482 | val NELBO = -202.2287
# Epoch 196 | train NELBO = -960.8522 | val NELBO = -187.8731
# Epoch 197 | train NELBO = -963.2234 | val NELBO = -208.5814
# Epoch 198 | train NELBO = -983.4377 | val NELBO = -187.6222
# Epoch 199 | train NELBO = -964.9191 | val NELBO = -202.6724
# Epoch 200 | train NELBO = -965.6982 | val NELBO = -200.3613
# Restored parameters from epoch 197 (NELBO=-208.5814)

# %%
# Forecast on the holdout test window
y_obs = torch.from_numpy(val_series) \
              .unsqueeze(0).unsqueeze(-1) \
              .float()  # [1, 50, 1]

# Rollout beyond val
y_pred, y_var = model.forecast(
    y_obs,
    horizon=horizon,
    use_map=False,
    num_samples=100
)

y_pred = y_pred.detach().numpy().flatten()
y_std = np.sqrt(y_var.detach().numpy().flatten())

# %%
# Plot train+val, true test, and forecasts
plt.figure(figsize=(8,4))
# Plot everything up to 250
plt.plot(
    np.arange(5*window),
    series[:5*window],
    label="Train+Val Observed"
)
# True test
t_test = np.arange(5*window, 5*window+horizon)
plt.plot(t_test, test_true, '--k', label="True Test")
# Forecast mean + 95% CI
plt.plot(t_test, y_pred, 'r', label="Forecast")
plt.fill_between(
    t_test,
    y_pred - 1.96*y_std,
    y_pred + 1.96*y_std,
    color='r',
    alpha=0.2
)
plt.axvline(5*window, color='grey', linestyle=':')
plt.legend()
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("GPSSM: Train/Val/Test Forecast")
plt.tight_layout()
plt.show()

# %%
# Compute Test RMSE
rmse = np.sqrt(np.mean((y_pred - test_true)**2))
print(f"Test RMSE over horizon of {horizon} timesteps: {rmse:.4f}")
# Out:
# Test RMSE over horizon of 30 timesteps: 0.5166
